# %% [markdown]
# ![Finance Toolkit](https://github.com/JerBouma/FinanceToolkit/assets/46355364/198d47bd-e1b3-492d-acc4-5d9f02d1d009)
#
# **The FinanceToolkit** is an open-source toolkit in which all relevant financial ratios (100+), indicators and performance measurements are written down in the most simplistic way allowing for complete transparency of the calculation method. This allows you to not have to rely on metrics from other providers and, given a financial statement, allow for efficient manual calculations. This leads to one uniform method of calculation being applied that is available and understood by everyone.

# %% [markdown]
# # Installation
# To install the FinanceToolkit it simply requires the following:
#
# ```
# pip install financetoolkit -U
# ```
#
# From within Python use:
#
# ```python
# from financetoolkit import Toolkit
# ```
#
# To be able to get started, you need to obtain an API Key from FinancialModelingPrep. This is used to gain access to 30+ years of financial statement both annually and quarterly. Note that the Free plan is limited to 250 requests each day, 5 years of data and only features companies listed on US exchanges.
#
# ___
#
# <b><div align="center">Obtain an API Key from FinancialModelingPrep <a href="https://www.jeroenbouma.com/fmp" target="_blank">here</a>.</div></b>
# ___
#
# Through the link you are able to subscribe for the free plan and also premium plans at a **15% discount**. This is an affiliate link and thus supports the project at the same time. I have chosen FinancialModelingPrep as a source as I find it to be the most transparent, reliable and at an affordable price. When you notice that data is inaccurate or have any other issue related to the data, note that I simply provide the means to access this data and I am not responsible for the accuracy of the data itself. For this, use <a href="https://site.financialmodelingprep.com/contact" target="_blank">their contact form</a> or provide the data yourself.
#
# The current Notebook is revolved around the Economics class. If you are interested in the other modules, you can find the related Notebooks below. **Please view the documentation <a href="https://www.jeroenbouma.com/projects/financetoolkit/docs/economics" target="_blank">here</a> to find all the available indicators.**
#
# <style>
# .button {
#   color: #fff !important;
#   background-color: #58abc4;
#   display: inline-block;
#   margin-bottom: 0.25em;
#   padding: 0.5em 1em;
#   font-family: -apple-system,BlinkMacSystemFont,"Roboto","Segoe UI","Helvetica Neue","Lucida Grande",Arial,sans-serif;
#   font-size: .75em;
#   font-weight: bold;
#   text-align: center;
#   text-decoration: none;
#   border-width: 0;
#   border-radius: 4px;
#   cursor: pointer;
# }
#
# .button-current {
#   background-color: #d67f05;
# }
#
# a:hover {
#   color: #fff !important;
#   font-weight: normal !important;
# }
# </style>
#
# <div style="display: flex; justify-content: space-between;" class="show-on-desktop">
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//getting-started" target="_blank" class="button" style="flex: 1;margin-right:5px"">Toolkit</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//discovery-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Discovery</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//ratios-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Ratios</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//models-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Models</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//options-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Options</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//technicals-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Technicals</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//risk-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Risk</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//performance-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Performance</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//economics-module"  target="_blank" class="button button-current" style="flex: 1;margin-right:5px">Economics</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//fixed-income-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Fixed income</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//portfolio-module" target="_blank" class="button" style="flex: 1; ">Portfolio</a>
# </div>

# %%
from financetoolkit import Economics

# %% [markdown]
# The Economics module which includes a variety of key economic indicators. You can use the Economics class by importing it directly or after initialization of `Toolkit` by calling the `economics` class. In this example, the class is imported directly.

# %%
economics = Economics(start_date="2015-01-01")

# %% [markdown]
# For example, it is possible to show the Consumer Confidence Index (CCI) and the Producer Price Index (PPI) over time for 60+ countries.

# %%
cci = economics.get_consumer_confidence_index()

display(cci)

cci.loc[:, ["United States", "South Africa", "China", "Spain", "Germany"]].plot(
    title="Consumer Confidence Index (CCI) for USA, South Africa, China, Spain and Germany",
    figsize=(15, 3),
    xlabel="Date",
    ylabel="CPI (Base 100 = 2015)",
    grid=True,
)
# Out:
#               A5M  Australia  Austria   Belgium    Brazil     Chile    China  \
# 2015-01   99.9467    99.4185  99.5896  100.2045   98.9846  100.7742  99.3666
# 2015-02  100.3918    99.6901  99.5989  100.5360   98.4434  100.5348  99.6623
# 2015-03  100.6589    99.7901  99.7399  100.7043   98.1273   99.8888  99.7122
# 2015-04  100.7697    99.7739  99.8546  100.8013   98.0310   99.2052  99.7232
# 2015-05  100.7251    99.7434  99.8384  100.8606   97.9336   98.7218  99.6383
# ...           ...        ...      ...       ...       ...       ...      ...
# 2024-11   97.0821    99.1153  98.2588   99.8849  100.9511   97.4865  93.9932
# 2024-12   97.0990    99.1802  98.0648   99.6388  100.5772   97.7794  94.0730
# 2025-01   97.1477    99.1720  98.0220   99.4361  100.0626   98.1792  94.2154
# 2025-02       NaN    99.2306  98.1243   99.2697   99.6525   98.6242      NaN
# 2025-03       NaN    99.3998  98.3440   98.9869   99.3999       NaN      NaN
#
#          Colombia  Costa Rica  Czech Republic  ...  Slovakia  Slovenia  \
# 2015-01  101.7924     99.8357        102.0786  ...  101.8130  100.5431
# 2015-02  101.1158     99.8234        101.8918  ...  102.0204  100.7477
# 2015-03  100.5614     99.7755        101.9225  ...  102.1072  101.0579
# 2015-04  100.6059     99.6247        102.0192  ...  101.9904  101.4549
# 2015-05  100.8301     99.2588        102.1205  ...  101.7914  101.6348
# ...           ...         ...             ...  ...       ...       ...
# 2024-11   98.6503    103.7198        100.0887  ...   99.7910   98.1580
# 2024-12   98.8231         NaN        100.0819  ...   99.4996   98.1798
# 2025-01   98.6607         NaN        100.0620  ...   99.3192   98.0503
# 2025-02   98.0688         NaN        100.0733  ...   99.3611   97.9363
# 2025-03       NaN         NaN        100.0300  ...   99.5581   98.0569
#
#          South Africa  South Korea     Spain    Sweden  Switzerland    Turkey  \
# 2015-01      100.1461     100.3276  101.0382  100.1023     100.3927  100.5605
# 2015-02       99.9190     100.3767  101.5976  100.1113     100.4225  100.2755
# 2015-03       99.5697     100.4142  102.0146  100.1537     100.5662   99.9977
# 2015-04       99.0939     100.4807  102.1538  100.1585     100.7254   99.9213
# 2015-05       98.6413     100.4046  102.0141  100.2248     100.7661   99.9356
# ...               ...          ...       ...       ...          ...       ...
# 2024-11       99.4903      99.5131  100.4728  100.5818      97.6258   97.6385
# 2024-12       99.2227      98.9437  100.5152  100.3399      97.6821   97.8486
# 2025-01       98.6868      98.7896  100.5129  100.0578      97.8026   98.0776
# 2025-02       97.9958      98.9022  100.5000   99.4317      97.9461   98.5201
# 2025-03       97.2545      98.9885       NaN   98.5288          NaN   99.2026
#
#          United Kingdom  United States
# 2015-01        101.9596       101.1682
# 2015-02        102.2264       101.1707
# 2015-03        102.4136       101.0748
# 2015-04        102.4068       101.0204
# 2015-05        102.2780       100.9405
# ...                 ...            ...
# 2024-11         99.0384        98.4625
# 2024-12         99.0410        98.4836
# 2025-01         98.9162        98.1936
# 2025-02         99.0068        97.5794
# 2025-03         99.1128        96.8127
#
# [123 rows x 49 columns]
# <Axes: title={'center': 'Consumer Confidence Index (CCI) for USA, South Africa, China, Spain and Germany'}, xlabel='Date', ylabel='CPI (Base 100 = 2015)'>

# %% [markdown]
# But also, the Long Term Interest Rates (LTIR) and the Short Term Interest Rates (STIR)

# %%
long_term_interest_rates = (
    economics.get_long_term_interest_rate(period="quarterly") * 100
)

long_term_interest_rates.loc[
    :, ["United States", "United Kingdom", "Japan", "Germany", "France", "Canada"]
].plot(
    figsize=(15, 5),
    title="Long Term Interest Rates",
    grid=True,
    xlabel="Date",
    ylabel="Interest Rate (%)",
)

short_term_interest_rates = (
    economics.get_short_term_interest_rate(period="quarterly") * 100
)

short_term_interest_rates.loc[
    :, ["United States", "United Kingdom", "Japan", "Germany", "France", "Canada"]
].plot(
    figsize=(15, 5),
    title="Short Term Interest Rates",
    grid=True,
    xlabel="Date",
    ylabel="Interest Rate (%)",
)
# Out:
# <Axes: title={'center': 'Short Term Interest Rates'}, xlabel='Date', ylabel='Interest Rate (%)'>

# %% [markdown]
# It is also possible to see how a housing prices have changed over time in each country. This can reflect the economic situation of a country and policies in place by the government.

# %%
house_prices = economics.get_house_prices()

display(house_prices)

house_prices[
    ["Australia", "Turkey", "United States", "United Kingdom", "Spain", "Brazil"]
].plot(
    figsize=(15, 5),
    title="House Prices Index",
    grid=True,
    xlabel="Date",
    ylabel="House Prices (Base 100 = 2015)",
)
# Out:
#       Australia   Austria   Belgium    Brazil  Bulgaria    Canada     Chile  \
# 2015   100.0000  100.0000  100.0000  100.0000  100.0000  100.0000  100.0000
# 2016   104.8458  105.3033  100.8316   91.8194  105.2420  109.0775  102.8667
# 2017   112.2037  108.6605  102.3238   88.9351  109.3561  120.4274  108.5751
# 2018   108.7694  112.7711  103.2827   85.0523  113.8527  122.8666  117.3649
# 2019   102.5101  117.5216  105.6010   82.1802  118.3054  122.6708  124.9467
# 2020   106.7001  125.1655  109.1309   79.6684  124.7374  129.6744  126.5453
# 2021   122.7003  136.6784  113.4317   74.6714  127.5324  144.5144  135.4807
# 2022   124.3772  141.7740  108.6407   71.7193  125.5494  152.3671  130.7236
# 2023   118.9718  127.1336  104.8270   72.1131  127.0774  143.8436  131.7276
# 2024   121.2015  122.8504  106.5569   73.9123  141.0770  144.7018       NaN
#
#          China  Colombia   Croatia  ...  Slovakia  Slovenia  South Africa  \
# 2015  100.0000  100.0000  100.0000  ...  100.0000  100.0000      100.0000
# 2016  109.8779  102.7365  102.0184  ...  106.9972  103.7368       98.7032
# 2017  122.4894  105.7355  105.0060  ...  112.0824  110.6012       98.4021
# 2018  127.0653  107.8626  109.8475  ...  118.1839  117.8834       97.9798
# 2019  128.3166  109.3483  118.3683  ...  126.0513  124.0486       96.7991
# 2020  129.7477  109.6353  126.7656  ...  135.1714  130.1634       96.2308
# 2021  133.5648  108.5109  132.5083  ...  139.3704  140.6241       98.7577
# 2022  132.2327  102.8332  137.6106  ...  141.7862  146.8421       96.1986
# 2023  131.7182  102.4311  141.8138  ...  128.3224  146.3893       91.7925
# 2024  133.3831  106.5390  151.6449  ...  128.6611  153.8267       88.8750
#
#       South Korea     Spain    Sweden  Switzerland    Turkey  United Kingdom  \
# 2015     100.0000  100.0000  100.0000     100.0000  100.0000        100.0000
# 2016     100.2929  104.4196  107.2943     101.8163  105.9855        105.6606
# 2017      99.5477  109.2339  112.4683     102.9394  105.5429        108.4710
# 2018      99.5207  114.9663  108.7032     104.7641   99.7532        109.6904
# 2019      98.5304  119.6432  109.1636     108.8881   91.3521        109.1344
# 2020     100.8826  122.2565  112.7513     114.0938   99.6794        111.7189
# 2021     107.0373  124.0123  121.4891     121.7142  113.7453        117.9647
# 2022     104.6819  125.0604  118.0323     127.5397  155.3475        119.1722
# 2023      94.1692  123.4391  104.8716     127.2668  196.7197        111.9294
# 2024      92.2993  128.7086  102.0387     129.5293  177.0317        110.1330
#
#       United States
# 2015       100.0000
# 2016       104.5064
# 2017       108.9949
# 2018       113.3151
# 2019       117.3196
# 2020       125.1380
# 2021       140.0627
# 2022       149.2840
# 2023       150.8588
# 2024       155.1721
#
# [10 rows x 50 columns]
# <Axes: title={'center': 'House Prices Index'}, xlabel='Date', ylabel='House Prices (Base 100 = 2015)'>

# %% [markdown]
# Given that the models layer for the economics module, as part of the Finance Toolkit architecture, mostly just collects data. It is also possible to directly use this functions instead. As an example, to get the unemployment rates for all countries.

# %%
from financetoolkit.economics import oecd_model

oecd_model.get_unemployment_rate(period="quarterly")
# Out:
#         Australia   Austria   Belgium  Bulgaria    Canada     Chile  Colombia  \
# 1955Q1        NaN       NaN       NaN       NaN  0.048000       NaN       NaN
# 1955Q2        NaN       NaN       NaN       NaN  0.044333       NaN       NaN
# 1955Q3        NaN       NaN       NaN       NaN  0.040667       NaN       NaN
# 1955Q4        NaN       NaN       NaN       NaN  0.038333       NaN       NaN
# 1956Q1        NaN       NaN       NaN       NaN  0.037000       NaN       NaN
# ...           ...       ...       ...       ...       ...       ...       ...
# 2024Q1   0.038904  0.049000  0.057000  0.045667  0.059000  0.085997  0.108042
# 2024Q2   0.040496  0.051000  0.055667  0.040667  0.063000  0.081471  0.102023
# 2024Q3   0.041424  0.053667  0.056333  0.040667  0.065667  0.085162  0.098507
# 2024Q4   0.040068  0.054000  0.059000  0.040000  0.067333  0.085873  0.097792
# 2025Q1        NaN       NaN       NaN       NaN  0.066333       NaN       NaN
#
#         Costa Rica   Croatia  Czech Republic  ...  Portugal  Slovakia  \
# 1955Q1         NaN       NaN             NaN  ...       NaN       NaN
# 1955Q2         NaN       NaN             NaN  ...       NaN       NaN
# 1955Q3         NaN       NaN             NaN  ...       NaN       NaN
# 1955Q4         NaN       NaN             NaN  ...       NaN       NaN
# 1956Q1         NaN       NaN             NaN  ...       NaN       NaN
# ...            ...       ...             ...  ...       ...       ...
# 2024Q1    0.078074  0.054000        0.028333  ...  0.064333  0.055667
# 2024Q2    0.085179  0.051000        0.027333  ...  0.064667  0.054333
# 2024Q3    0.066138  0.048667        0.027333  ...  0.064667  0.052667
# 2024Q4    0.068753  0.046333        0.027000  ...  0.065333  0.051667
# 2025Q1         NaN       NaN             NaN  ...       NaN       NaN
#
#         Slovenia  South Korea     Spain    Sweden  Switzerland    Turkey  \
# 1955Q1       NaN          NaN       NaN       NaN          NaN       NaN
# 1955Q2       NaN          NaN       NaN       NaN          NaN       NaN
# 1955Q3       NaN          NaN       NaN       NaN          NaN       NaN
# 1955Q4       NaN          NaN       NaN       NaN          NaN       NaN
# 1956Q1       NaN          NaN       NaN       NaN          NaN       NaN
# ...          ...          ...       ...       ...          ...       ...
# 2024Q1  0.034333     0.028000  0.118000  0.082000     0.040934  0.088000
# 2024Q2  0.035333     0.028000  0.115667  0.082667     0.042538  0.087667
# 2024Q3  0.040667     0.025333  0.113000  0.085333     0.045302  0.087333
# 2024Q4  0.036333     0.030333  0.107333  0.084667     0.044866  0.085667
# 2025Q1       NaN     0.028333       NaN       NaN          NaN       NaN
#
#         United Kingdom  United States
# 1955Q1             NaN       0.047333
# 1955Q2             NaN       0.044000
# 1955Q3             NaN       0.041000
# 1955Q4             NaN       0.042333
# 1956Q1             NaN       0.040333
# ...                ...            ...
# 2024Q1           0.043       0.038333
# 2024Q2           0.042       0.040000
# 2024Q3           0.043       0.041667
# 2024Q4           0.044       0.041333
# 2025Q1             NaN       0.041000
#
# [281 rows x 44 columns]
