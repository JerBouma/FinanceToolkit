# %% [markdown]
# ![Finance Toolkit](https://github.com/JerBouma/FinanceToolkit/assets/46355364/198d47bd-e1b3-492d-acc4-5d9f02d1d009)
#
# **The FinanceToolkit** is an open-source toolkit in which all relevant financial ratios (100+), indicators and performance measurements are written down in the most simplistic way allowing for complete transparency of the calculation method. This allows you to not have to rely on metrics from other providers and, given a financial statement, allow for efficient manual calculations. This leads to one uniform method of calculation being applied that is available and understood by everyone.

# %% [markdown]
# # Installation
# To install the FinanceToolkit it simply requires the following:
#
# ```
# pip install financetoolkit -U
# ```
#
# From within Python use:
#
# ```python
# from financetoolkit import Toolkit
# ```
#
# To be able to get started, you need to obtain an API Key from FinancialModelingPrep. This is used to gain access to 30+ years of financial statement both annually and quarterly. Note that the Free plan is limited to 250 requests each day, 5 years of data and only features companies listed on US exchanges.
#
# ___
#
# <b><div align="center">Obtain an API Key from FinancialModelingPrep <a href="https://www.jeroenbouma.com/fmp" target="_blank">here</a>.</div></b>
# ___
#
# Through the link you are able to subscribe for the free plan and also premium plans at a **15% discount**. This is an affiliate link and thus supports the project at the same time. I have chosen FinancialModelingPrep as a source as I find it to be the most transparent, reliable and at an affordable price. When you notice that data is inaccurate or have any other issue related to the data, note that I simply provide the means to access this data and I am not responsible for the accuracy of the data itself. For this, use <a href="https://site.financialmodelingprep.com/contact" target="_blank">their contact form</a> or provide the data yourself.
#
# The current Notebook is revolved around the Ratios class. If you are interested in the other modules, you can find the related Notebooks below. **Please view the documentation <a href="https://www.jeroenbouma.com/projects/financetoolkit/docs" target="_blank">here</a> to find all the available functionality.**
#
# <style>
# .button {
#   color: #fff !important;
#   background-color: #58abc4;
#   display: inline-block;
#   margin-bottom: 0.25em;
#   padding: 0.5em 1em;
#   font-family: -apple-system,BlinkMacSystemFont,"Roboto","Segoe UI","Helvetica Neue","Lucida Grande",Arial,sans-serif;
#   font-size: .75em;
#   font-weight: bold;
#   text-align: center;
#   text-decoration: none;
#   border-width: 0;
#   border-radius: 4px;
#   cursor: pointer;
# }
#
# .button-current {
#   background-color: #d67f05;
# }
#
# a:hover {
#   color: #fff !important;
#   font-weight: normal !important;
# }
# </style>
#
# <div style="display: flex; justify-content: space-between;" class="show-on-desktop">
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//getting-started" target="_blank" class="button" style="flex: 1;margin-right:5px"">Toolkit</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//discovery-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Discovery</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//ratios-module" target="_blank" class="button-current" style="flex: 1;margin-right:5px">Ratios</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//models-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Models</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//options-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Options</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//technicals-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Technicals</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//risk-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Risk</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//performance-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Performance</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//economics-module"  target="_blank" class="button" style="flex: 1;margin-right:5px">Economics</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//fixedincome-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Fixed income</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//portfolio-module" target="_blank" class="button" style="flex: 1; ">Portfolio</a>
# </div>

# %%
import pandas as pd

from financetoolkit import Toolkit

API_KEY = "FINANCIAL_MODELING_PREP_API_KEY"

# %% [markdown]
# **Initializing only is required once.** This is the case for any function so once you have obtained a balance sheet statement, it will be stored accordingly which means that requests to FinancialModelingPrep, the source used in these examples, are kept to a minimum. Note that in this example annual data is used but by adding `quarterly=True` to the Toolkit initialization, quarterly data can also be collected. Note that this requires a Premium subscription from FMP.

# %%
# Initialize the Toolkit with company tickers
companies = Toolkit(
    ["AAPL", "AMZN", "META", "WMT"], api_key=API_KEY, start_date="2005-01-01"
)

# %% [markdown]
# After initialization of `Toolkit`, you can get access to the Ratios module which includes over 50 different ratios. This can be done by calling the `ratios` property. Please view the documentation <a href="https://www.jeroenbouma.com/projects/financetoolkit/docs/ratios" target="_blank">here</a> to find all the available ratios.
#
# Within this ratios module, the distinction is made between `collect_` and `get_`. The former obtains a collection of ratios (e.g. all solvency ratios) whereas the latter obtains a specific ratio. You will note that it will collect data first, this is done only once so that the ratios can be calculated efficiently. For example, let's start with getting all ratios.

# %%
companies.ratios.collect_all_ratios()
# Out:
# Obtaining financial statements: 100%|██████████| 3/3 [00:03<00:00,  1.07s/it]
# Obtaining historical data: 100%|██████████| 5/5 [00:00<00:00,  9.20it/s]
#                                                    2005          2006  \
# AAPL Days of Inventory Outstanding                  NaN        5.7875
#      Days of Sales Outstanding                      NaN       39.2779
#      Operating Cycle                                NaN       45.0654
#      Days of Accounts Payable Outstanding           NaN       68.7718
#      Cash Conversion Cycle                          NaN      -23.7064
# ...                                                 ...           ...
# WMT  EV-to-EBIT                                  9.4932        8.9978
#      EV-to-EBITDA                                7.5266        7.1427
#      EV-to-Operating-Cash-Flow                  10.7546        9.4167
#      Tangible Asset Value                 38593000000.0 41074000000.0
#      Net Current Asset Value              -4397000000.0 -5002000000.0
#
#                                                    2007           2008  \
# AAPL Days of Inventory Outstanding               7.0918          7.314
#      Days of Sales Outstanding                   52.258        49.0709
#      Operating Cycle                            59.3498        56.3849
#      Days of Accounts Payable Outstanding       96.2465        89.7359
#      Cash Conversion Cycle                     -36.8967        -33.351
# ...                                                 ...            ...
# WMT  EV-to-EBIT                                  8.8254         9.3267
#      EV-to-EBITDA                                 6.616         7.1621
#      EV-to-Operating-Cash-Flow                   8.5164         9.9627
#      Tangible Asset Value                 47814000000.0  48729000000.0
#      Net Current Asset Value              -5166000000.0 -10869000000.0
#
#                                                    2009          2010  \
# AAPL Days of Inventory Outstanding               7.5193        6.9509
#      Days of Sales Outstanding                  48.7556       41.9169
#      Operating Cycle                            56.2749       48.8678
#      Days of Accounts Payable Outstanding       86.7454        81.306
#      Cash Conversion Cycle                     -30.4705      -32.4382
# ...                                                 ...           ...
# WMT  EV-to-EBIT                                   8.361        8.1018
#      EV-to-EBITDA                                6.4339        6.1307
#      EV-to-Operating-Cash-Flow                     8.21        7.2654
#      Tangible Asset Value                 50025000000.0 57110000000.0
#      Net Current Asset Value              -6441000000.0 -7230000000.0
#
#                                                    2011          2012  \
# AAPL Days of Inventory Outstanding                5.175        3.2554
#      Days of Sales Outstanding                  36.4852       35.4592
#      Operating Cycle                            41.6601       38.7146
#      Days of Accounts Payable Outstanding       75.4773        74.389
#      Cash Conversion Cycle                     -33.8172      -35.6744
# ...                                                 ...           ...
# WMT  EV-to-EBIT                                  8.1188        9.1088
#      EV-to-EBITDA                                6.4037        6.8182
#      EV-to-Operating-Cash-Flow                   8.9876        9.7509
#      Tangible Asset Value                 54892000000.0 55514000000.0
#      Net Current Asset Value              -6591000000.0 -7325000000.0
#
#                                                     2013          2014  \
# AAPL Days of Inventory Outstanding                4.3739        6.2997
#      Days of Sales Outstanding                   42.0003       47.7828
#      Operating Cycle                             46.3742       54.0824
#      Days of Accounts Payable Outstanding          74.54       85.4527
#      Cash Conversion Cycle                      -28.1658      -31.3703
# ...                                                  ...           ...
# WMT  EV-to-EBIT                                   9.7414        10.838
#      EV-to-EBITDA                                 7.3072         8.024
#      EV-to-Operating-Cash-Flow                   10.3657       12.3316
#      Tangible Asset Value                  61760000000.0 63320000000.0
#      Net Current Asset Value              -11878000000.0 -8160000000.0
#
#                                                    2015          2016  \
# AAPL Days of Inventory Outstanding               5.8102        6.2247
#      Days of Sales Outstanding                  44.9482       50.4763
#      Operating Cycle                            50.7584       56.7011
#      Days of Accounts Payable Outstanding        85.572      101.1074
#      Cash Conversion Cycle                     -34.8136      -44.4063
# ...                                                 ...           ...
# WMT  EV-to-EBIT                                  7.9462        9.9551
#      EV-to-EBITDA                                5.8654        7.0601
#      EV-to-Operating-Cash-Flow                    7.458        8.6506
#      Tangible Asset Value                 67835000000.0 66916000000.0
#      Net Current Asset Value              -1994000000.0 -4380000000.0
#
#                                                    2017           2018  \
# AAPL Days of Inventory Outstanding               9.0404         9.8195
#      Days of Sales Outstanding                  51.7261        58.1785
#      Operating Cycle                            60.7665         67.998
#      Days of Accounts Payable Outstanding      105.4983       111.5912
#      Cash Conversion Cycle                     -44.7318       -43.5932
# ...                                                 ...            ...
# WMT  EV-to-EBIT                                 14.1709        17.7282
#      EV-to-EBITDA                                9.5845         9.6135
#      EV-to-Operating-Cash-Flow                   9.9839        10.5054
#      Tangible Asset Value                 63498000000.0  62580000000.0
#      Net Current Asset Value              -9239000000.0 -18857000000.0
#
#                                                     2019           2020  \
# AAPL Days of Inventory Outstanding                9.0944         8.7903
#      Days of Sales Outstanding                   66.4971        55.3447
#      Operating Cycle                             75.5915         64.135
#      Days of Accounts Payable Outstanding       115.2021        95.2889
#      Cash Conversion Cycle                      -39.6106       -31.1539
# ...                                                  ...            ...
# WMT  EV-to-EBIT                                  28.7385        20.5307
#      EV-to-EBITDA                                11.7094        14.5709
#      EV-to-Operating-Cash-Flow                   13.7692        18.2057
#      Tangible Asset Value                  48453000000.0  50479000000.0
#      Net Current Asset Value              -15580000000.0 -15984000000.0
#
#                                                    2021          2022  \
# AAPL Days of Inventory Outstanding               9.1181        9.4097
#      Days of Sales Outstanding                  44.3762       52.0377
#      Operating Cycle                            53.4943       61.4474
#      Days of Accounts Payable Outstanding       83.1683       97.0504
#      Cash Conversion Cycle                      -29.674       -35.603
# ...                                                 ...           ...
# WMT  EV-to-EBIT                                 19.6845       21.4607
#      EV-to-EBITDA                               13.2493       11.9752
#      EV-to-Operating-Cash-Flow                  12.3774       18.1254
#      Tangible Asset Value                 58548000000.0 62877000000.0
#      Net Current Asset Value              -2578000000.0 -6309000000.0
#
#                                                     2023           2024
# AAPL Days of Inventory Outstanding                9.6109         11.814
#      Days of Sales Outstanding                   58.0504        59.3786
#      Operating Cycle                             67.6613        71.1926
#      Days of Accounts Payable Outstanding       108.0033       114.1501
#      Cash Conversion Cycle                      -40.3419       -42.9575
# ...                                                  ...            ...
# WMT  EV-to-EBIT                                  24.7423        33.2665
#      EV-to-EBITDA                                15.4039        20.3477
#      EV-to-Operating-Cash-Flow                   16.7562        22.1355
#      Tangible Asset Value                  55817000000.0  62458000000.0
#      Net Current Asset Value              -16543000000.0 -15538000000.0
#
# [268 rows x 20 columns]

# %% [markdown]
# Given that you might not be interested in all of them, it is possible to also call each and every single one seperately.

# %%
companies.ratios.get_effective_tax_rate()
# Out:
# date   2005   2006    2007   2008   2009   2010   2011   2012   2013    2014  \
# AAPL 0.2645 0.2942  0.3019 0.2989 0.2856 0.2442 0.2422 0.2516 0.2615  0.2613
# AMZN  0.222  0.496  0.2788 0.2741 0.2179 0.2351 0.3116 0.7868 0.3182 -1.5045
# META    NaN    NaN -0.0222   -0.0 0.0984 0.3988   0.41 0.8927 0.4553  0.4012
# WMT   0.347 0.3343  0.3356  0.342 0.3419 0.3235  0.322 0.3256 0.3101  0.3287
#
# date   2015   2016   2017   2018   2019   2020   2021   2022   2023   2024
# AAPL 0.2637 0.2556 0.2456 0.1834 0.1594 0.1443  0.133  0.162 0.1472 0.2409
# AMZN 0.6059 0.3661  0.202 0.1063 0.1699 0.1184 0.1256 0.5419 0.1896    NaN
# META 0.4046 0.1838 0.2263 0.1281  0.255 0.1216 0.1674  0.195 0.1756    NaN
# WMT   0.322 0.3031 0.3027 0.3042 0.3736 0.2443 0.3335 0.2544 0.3364 0.2553

# %% [markdown]
# Some of these ratios also include optional fields depending on whether there is room for different methods of calculation. E.g. whether you'd like to have the diluted average shares included in the calculation.

# %%
companies.ratios.collect_solvency_ratios(diluted=False, growth=True)
# Out:
# date                                2005    2006    2007    2008    2009  \
# AAPL Debt-to-Assets Ratio            NaN     NaN     NaN     NaN     NaN
#      Debt-to-Equity Ratio            NaN     NaN     NaN     NaN     NaN
#      Debt Service Coverage Ratio     NaN -0.1955   0.248  0.1625  0.2051
#      Equity Multiplier               NaN  2.4858  0.0523 -0.0376 -0.0713
#      Free Cash Flow Yield            NaN -0.4428  0.2016   3.271 -0.5748
#      Net-Debt to EBITDA Ratio        NaN  0.2505  -0.171 -0.1107 -0.6423
#      Cash Flow Coverage Ratio        NaN     NaN     NaN     NaN     NaN
#      CAPEX Coverage Ratio            NaN -0.6534  0.6418  0.4426  0.0465
#      Dividend CAPEX Coverage Ratio   NaN -0.6534  0.6418  0.4426  0.0465
# AMZN Debt-to-Assets Ratio            NaN -0.2773 -0.2772 -0.7656 -0.6301
#      Debt-to-Equity Ratio            NaN  -0.513 -0.6132 -0.8653 -0.6871
#      Debt Service Coverage Ratio     NaN -0.3248  0.1484  0.0057 -0.1359
#      Equity Multiplier               NaN 51.3253 -0.4402  -0.426 -0.2704
#      Free Cash Flow Yield            NaN  0.0919  0.0404  1.0388 -0.2048
#      Net-Debt to EBITDA Ratio        NaN -0.5167 -4.1695  0.5988  0.0133
#      Cash Flow Coverage Ratio        NaN  0.1226   0.863  3.0193  2.1495
#      CAPEX Coverage Ratio            NaN -0.0955  0.9299 -0.1875  0.7324
#      Dividend CAPEX Coverage Ratio   NaN -0.0955  0.9299 -0.1875  0.7324
# META Debt-to-Assets Ratio            NaN -0.0955  0.9299 -0.1875  0.7324
#      Debt-to-Equity Ratio            NaN -0.0955  0.9299 -0.1875  0.7324
#      Debt Service Coverage Ratio     NaN -0.0955  0.9299 -0.1875  0.7324
#      Equity Multiplier               NaN -0.0955  0.9299 -0.1875  0.7324
#      Free Cash Flow Yield            NaN -0.0955  0.9299 -0.1875    -inf
#      Net-Debt to EBITDA Ratio        NaN -0.0955  0.9299 -0.1875    -inf
#      Cash Flow Coverage Ratio        NaN -0.0955  0.9299 -0.1875    -inf
#      CAPEX Coverage Ratio            NaN -0.0955  0.9299 -0.1875 -0.0783
#      Dividend CAPEX Coverage Ratio   NaN -0.0955  0.9299 -0.1875 -0.0783
# WMT  Debt-to-Assets Ratio            NaN  0.0738 -0.0812  0.0585 -0.0545
#      Debt-to-Equity Ratio            NaN  0.1458 -0.1384  0.0965 -0.0679
#      Debt Service Coverage Ratio     NaN -0.0477  0.0435 -0.0497  0.0938
#      Equity Multiplier               NaN  5.1548 -0.0033 -0.0119  0.0099
#      Free Cash Flow Yield            NaN  0.4562  0.3991  0.0276  1.2806
#      Net-Debt to EBITDA Ratio        NaN  0.1541 -0.1253  0.1328 -0.1434
#      Cash Flow Coverage Ratio        NaN -0.0504  0.1378 -0.1184  0.2035
#      CAPEX Coverage Ratio            NaN  0.0377   0.063  0.0587  0.4772
#      Dividend CAPEX Coverage Ratio   NaN  0.0371  0.0572  0.0065  0.3817
#
# date                                  2010    2011    2012    2013    2014  \
# AAPL Debt-to-Assets Ratio              NaN     NaN     NaN     inf  0.8584
#      Debt-to-Equity Ratio              NaN     NaN     NaN     inf  1.3044
#      Debt Service Coverage Ratio    0.3329  0.3617  0.1864 -0.1933 -0.2843
#      Equity Multiplier             -0.0044 -0.0031 -0.0251  0.0556   0.178
#      Free Cash Flow Yield           0.1829  0.4309  0.0273  0.0061 -0.1533
#      Net-Debt to EBITDA Ratio      -0.0785 -0.5247 -0.3341 -1.2571  6.5191
#      Cash Flow Coverage Ratio          NaN     NaN     NaN    -1.0 -0.4653
#      CAPEX Coverage Ratio           0.0468 -0.4256  0.0741  0.0932  0.0291
#      Dividend CAPEX Coverage Ratio  0.0468 -0.4256 -0.1507 -0.3611  0.0437
# AMZN Debt-to-Assets Ratio           0.8736  0.6422     1.1  0.0969   0.776
#      Debt-to-Equity Ratio           0.9499  0.9529   1.563  0.1371  1.1872
#      Debt Service Coverage Ratio   -0.1155  -0.573 -0.3851 -0.0899 -0.8056
#      Equity Multiplier             -0.0359  0.1205  0.2029  0.1179  0.1399
#      Free Cash Flow Yield          -0.3752  -0.147 -0.8652  2.0833  0.2252
#      Net-Debt to EBITDA Ratio      -0.2499  0.2472 -0.2427 -0.4204 -0.5171
#      Cash Flow Coverage Ratio      -0.5828 -0.4941 -0.6043 -0.0318 -0.4816
#      CAPEX Coverage Ratio          -0.5956 -0.3963 -0.4876  0.4394 -0.1204
#      Dividend CAPEX Coverage Ratio -0.5956 -0.3963 -0.4876  0.4394 -0.1204
# META Debt-to-Assets Ratio          -1.0179 -0.3243  0.4593 -0.8295  -0.782
#      Debt-to-Equity Ratio          -1.0248 -0.3684  0.4501 -0.8463  -0.789
#      Debt Service Coverage Ratio   -1.3005 -0.2637 -0.7382  4.1926  0.3207
#      Equity Multiplier             -1.3005 -0.5024 -0.0251 -0.0583 -0.0707
#      Free Cash Flow Yield              NaN     NaN    -1.0  3.7727 -0.1619
#      Net-Debt to EBITDA Ratio         -1.0 -0.6416 -0.9412 29.6822 -0.0961
#      Cash Flow Coverage Ratio         -1.0  0.5505  -0.701 11.9636  1.6405
#      CAPEX Coverage Ratio          -0.4928   0.073 -0.4893  1.3749 -0.0386
#      Dividend CAPEX Coverage Ratio -0.4928   0.073 -0.4893  1.3749 -0.0386
# WMT  Debt-to-Assets Ratio          -0.0627    0.14  0.0007 -0.0351  0.0379
#      Debt-to-Equity Ratio          -0.0983  0.2334   0.008 -0.0619  0.0391
#      Debt Service Coverage Ratio    0.0474   0.013 -0.0238  -0.092   0.001
#      Equity Multiplier             -0.0266  0.0213  0.0435 -0.0109 -0.0129
#      Free Cash Flow Yield           0.1924 -0.2777 -0.1125  0.0257 -0.2638
#      Net-Debt to EBITDA Ratio      -0.0921  0.1915  0.0559 -0.0551  0.0815
#      Cash Flow Coverage Ratio       0.1587 -0.2537 -0.0424  0.0412 -0.1314
#      CAPEX Coverage Ratio           0.0702 -0.1358 -0.0357  0.1052 -0.1062
#      Dividend CAPEX Coverage Ratio  0.0541  -0.138 -0.0527  0.0724 -0.1382
#
# date                                  2015    2016    2017    2018    2019  \
# AAPL Debt-to-Assets Ratio            0.456  0.2207  0.1394  0.0156  0.0198
#      Debt-to-Equity Ratio           0.7035   0.259  0.2717  0.2381  0.1175
#      Debt Service Coverage Ratio    0.0678 -0.1038 -0.2316  0.0051 -0.0113
#      Equity Multiplier              0.2116   0.093   0.075  0.1562  0.1598
#      Free Cash Flow Yield           0.5252  -0.294 -0.3107  0.3877 -0.4785
#      Net-Debt to EBITDA Ratio       0.4759  0.7556  0.4663  -0.181 -0.2874
#      Cash Flow Coverage Ratio      -0.2533 -0.3976 -0.2704  0.2183 -0.0506
#      CAPEX Coverage Ratio           0.1625 -0.3089  0.0268  0.1588  0.1368
#      Dividend CAPEX Coverage Ratio  0.2363  -0.269 -0.0252  0.1405 -0.0161
# AMZN Debt-to-Assets Ratio          -0.0445 -0.1667  0.5833 -0.2943  0.3768
#      Debt-to-Equity Ratio          -0.0891 -0.2551  0.7349 -0.4439  0.3381
#      Debt Service Coverage Ratio    9.4603  0.4492 -0.2576  1.5614 -0.0881
#      Equity Multiplier              0.0698 -0.0826  0.0075 -0.0971 -0.1097
#      Free Cash Flow Yield           0.7059  0.1767 -0.5788  1.0522  0.0042
#      Net-Debt to EBITDA Ratio      -0.5205  0.6634 -4.3337 -0.9551 13.8665
#      Cash Flow Coverage Ratio        0.535  0.2854 -0.5503  0.9068 -0.3425
#      CAPEX Coverage Ratio           0.8576 -0.0604 -0.3683   0.484 -0.0017
#      Dividend CAPEX Coverage Ratio  0.8576 -0.0604 -0.3683   0.484 -0.0017
# META Debt-to-Assets Ratio          -0.6034    -1.0     inf  4.6667 14.1765
#      Debt-to-Equity Ratio             -0.6    -1.0     inf     4.9  16.322
#      Debt Service Coverage Ratio   -0.0779  0.3366  0.2431 -0.3392 -0.4576
#      Equity Multiplier             -0.0096 -0.0086  0.0122  0.0252  0.0857
#      Free Cash Flow Yield           0.1648  0.6976 -0.0316  0.2077 -0.1081
#      Net-Debt to EBITDA Ratio      -0.1036  0.0274 -0.4282 -0.0551  -0.226
#      Cash Flow Coverage Ratio       2.2207     inf    -1.0 -0.8259 -0.9399
#      CAPEX Coverage Ratio           0.1436  0.0524  0.0028 -0.4151   0.143
#      Dividend CAPEX Coverage Ratio  0.1436  0.0524  0.0028 -0.4151   0.143
# WMT  Debt-to-Assets Ratio          -0.1059  0.0137 -0.0786  -0.016  0.1641
#      Debt-to-Equity Ratio          -0.1426  0.0206 -0.0468  0.0084  0.2669
#      Debt Service Coverage Ratio    0.0733 -0.1031 -0.0882 -0.2346  0.0887
#      Equity Multiplier             -0.0204 -0.0172  0.0204  0.0299  0.0566
#      Free Cash Flow Yield           1.2313 -0.1575 -0.0724 -0.0624 -0.2524
#      Net-Debt to EBITDA Ratio      -0.1777  0.0844  -0.034  0.0786  0.2015
#      Cash Flow Coverage Ratio       0.3809 -0.0346  0.2539 -0.1119 -0.2156
#      CAPEX Coverage Ratio           0.3231  0.0171  0.2442 -0.0505 -0.0483
#      Dividend CAPEX Coverage Ratio  0.2881 -0.0094  0.2152 -0.0646 -0.0368
#
# date                                  2020    2021    2022    2023      2024
# AAPL Debt-to-Assets Ratio           0.1826  0.0302 -0.0342 -0.1611   -0.0727
#      Debt-to-Equity Ratio           0.5673  0.1563  0.2082 -0.3163    0.0474
#      Debt Service Coverage Ratio    0.0402  0.3804 -0.1066  0.0141    -0.112
#      Equity Multiplier               0.193  0.2362  0.1772  0.0106   -0.0363
#      Free Cash Flow Yield          -0.2723 -0.0215   0.674  -0.382   -0.1424
#      Net-Debt to EBITDA Ratio       0.3842 -0.2244 -0.0133 -0.2266   -0.1168
#      Cash Flow Coverage Ratio       0.0274   0.155  0.2098  0.0793    0.1145
#      CAPEX Coverage Ratio           0.6694 -0.1497  0.2154 -0.1158     0.241
#      Dividend CAPEX Coverage Ratio  0.3378  0.0795  0.1742 -0.1102    0.1262
# AMZN Debt-to-Assets Ratio          -0.0638  0.0537  0.0939 -0.1516  -19.6504
#      Debt-to-Equity Ratio          -0.1128 -0.0682  0.1396 -0.2998    -8.132
#      Debt Service Coverage Ratio    0.0942 -0.0348 -0.5495  1.8363  -22.4376
#      Equity Multiplier              -0.043  -0.089 -0.0297 -0.0836   -2.6829
#      Free Cash Flow Yield          -0.3291 -1.5472  1.2644 -2.0457 -233.5874
#      Net-Debt to EBITDA Ratio       0.1779  0.5377  0.1776 -0.5429   -7.5851
#      Cash Flow Coverage Ratio       0.2847 -0.4916 -0.1616  0.8771   -8.6489
#      CAPEX Coverage Ratio          -0.2795 -0.5389 -0.0319   1.193    1.9741
#      Dividend CAPEX Coverage Ratio -0.2795 -0.5389 -0.0319   1.193    1.9741
# META Debt-to-Assets Ratio          -0.1357  0.2496  0.7129  0.1327  -30.5395
#      Debt-to-Equity Ratio          -0.1879  0.3386  0.9037  0.1494  -20.7092
#      Debt Service Coverage Ratio    0.1325  0.0144 -0.4387  0.1782   -4.2754
#      Equity Multiplier              0.0243  0.0068  0.0923  0.0611   -4.2171
#      Free Cash Flow Yield          -0.1598  0.3607  0.4241 -0.1827 -100.1988
#      Net-Debt to EBITDA Ratio      -0.3054  -0.715 -6.6513 -1.2833   58.9662
#      Cash Flow Coverage Ratio        0.034  0.1433 -0.5435  0.0062   -3.5087
#      CAPEX Coverage Ratio           0.0661  0.2119 -0.4831  0.6241    0.8371
#      Dividend CAPEX Coverage Ratio  0.0661  0.2119 -0.4831  0.6241    0.8371
# WMT  Debt-to-Assets Ratio           0.1576 -0.1822 -0.0655  0.0337    0.0041
#      Debt-to-Equity Ratio           0.2189 -0.1864 -0.1367  0.1246   -0.0349
#      Debt Service Coverage Ratio    -0.067 -0.0794  0.2198  -0.256    0.3232
#      Equity Multiplier              0.0706  0.0227 -0.0415  0.0016    0.0231
#      Free Cash Flow Yield          -0.3043  0.7547 -0.5638 -0.0174    -0.266
#      Net-Debt to EBITDA Ratio       0.2944 -0.3233 -0.1388  0.3715   -0.1699
#      Cash Flow Coverage Ratio      -0.2708  0.6358 -0.2605  0.1605    0.1902
#      CAPEX Coverage Ratio          -0.1207  0.4897  -0.475 -0.0727    0.0134
#      Dividend CAPEX Coverage Ratio -0.1067  0.4609 -0.4299 -0.0001     0.064

# %% [markdown]
# For all ratios, it is also possible to show the growth instead. E.g. if you are interested in the growth of the Price-to-Book ratio you can use the following:

# %%
companies.ratios.get_price_to_book_ratio(growth=True)
# Out:
# Date  2005    2006    2007    2008    2009    2010    2011   2012   2013  \
# AAPL   NaN -0.1011  0.6236 -0.7154  0.7505  0.0332 -0.2069 -0.133 0.0193
# AMZN   NaN -0.5251 -0.1544 -0.7476  0.3673  0.0567 -0.1402 0.3489 0.3719
# META   NaN -0.5251 -0.1544 -0.7476  0.3673    -1.0     NaN    inf 0.8126
# WMT    NaN -0.0871 -0.0989  0.1176 -0.0644 -0.0657  0.1129  0.064 0.0768
#
# Date    2014    2015    2016   2017    2018    2019   2020    2021    2022  \
# AAPL  0.4622 -0.1424 -0.0059  0.356  0.1271    1.08 1.3799  0.3417  -0.113
# AMZN -0.2983   0.804 -0.2187 0.1245  -0.185 -0.1298 0.1851 -0.3015 -0.5282
# META -0.3524  0.1728 -0.1581 0.2341 -0.3513  0.2834 0.0527  0.2523 -0.6641
# WMT   0.0851 -0.3213  0.1634 0.4679 -0.0667  0.3676  0.166 -0.0702 -0.0425
#
# Date   2023    2024
# AAPL 0.1767  0.3898
# AMZN 0.3475  7.5798
# META 1.3489 10.1946
# WMT  0.1945  0.5731

# %% [markdown]
# By default, the lag is set to 1 (one period) but it is possible to change this and add multiple lags as well.

# %%
companies.ratios.get_current_ratio(growth=True, lag=[1, 2, 3])
# Out:
# date        2005    2006    2007    2008    2009    2010    2011    2012  \
# AAPL Lag 1   NaN -0.2376  0.0506  0.1163  0.0384 -0.2666 -0.2003   -0.07
#      Lag 2   NaN     NaN  -0.199  0.1728  0.1591 -0.2385 -0.4135 -0.2563
#      Lag 3   NaN     NaN     NaN -0.1059  0.2179 -0.1499  -0.391 -0.4546
# AMZN Lag 1   NaN -0.1363  0.0437  -0.067  0.0255 -0.0038 -0.1141 -0.0455
#      Lag 2   NaN     NaN -0.0985 -0.0262 -0.0432  0.0217 -0.1174 -0.1544
#      Lag 3   NaN     NaN     NaN -0.1589 -0.0013 -0.0468 -0.0949 -0.1576
# META Lag 1   NaN     NaN     NaN     NaN     NaN     NaN  -0.113  1.0913
#      Lag 2   NaN     NaN     NaN     NaN     NaN     NaN     NaN   0.855
#      Lag 3   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# WMT  Lag 1   NaN  0.0001  0.0029 -0.0957  0.0856 -0.0157    0.02 -0.0055
#      Lag 2   NaN     NaN   0.003  -0.093 -0.0183  0.0686  0.0041  0.0144
#      Lag 3   NaN     NaN     NaN -0.0929 -0.0154 -0.0337    0.09 -0.0015
#
# date          2013    2014    2015    2016    2017    2018    2019    2020  \
# AAPL Lag 1  0.1222 -0.3566  0.0265    0.22 -0.0566 -0.1122  0.3594 -0.1146
#      Lag 2  0.0436 -0.2779 -0.3395  0.2523  0.1509 -0.1625  0.2069  0.2036
#      Lag 3 -0.1654 -0.3285 -0.2588 -0.1942  0.1814  0.0218  0.1386  0.0686
# AMZN Lag 1 -0.0438  0.0408 -0.0553 -0.0084 -0.0047  0.0559  -0.001 -0.0427
#      Lag 2 -0.0873 -0.0049 -0.0167 -0.0632  -0.013   0.051  0.0549 -0.0436
#      Lag 3 -0.1915 -0.0501 -0.0598  -0.025 -0.0675  0.0422    0.05  0.0099
# META Lag 1  0.1094 -0.1921  0.1717  0.0638  0.0794  -0.443 -0.3885  0.1481
#      Lag 2  1.3201 -0.1037 -0.0534  0.2464  0.1483 -0.3988 -0.6594 -0.2979
#      Lag 3  1.0579  0.8745  0.0502   0.007  0.3454 -0.3604 -0.6323 -0.6089
# WMT  Lag 1 -0.0542  0.0572  0.0987 -0.0384 -0.0754 -0.1185  0.0514 -0.0055
#      Lag 2 -0.0594 -0.0001  0.1616  0.0565 -0.1109 -0.1849 -0.0731  0.0456
#      Lag 3 -0.0405 -0.0056  0.0986   0.117 -0.0231 -0.2162  -0.143 -0.0782
#
# date          2021    2022    2023    2024
# AAPL Lag 1  -0.212 -0.1817  0.1236 -0.1222
#      Lag 2 -0.3023 -0.3551 -0.0805 -0.0137
#      Lag 3 -0.0515  -0.429 -0.2754 -0.1929
# AMZN Lag 1  0.0814 -0.1683  0.1063     0.0
#      Lag 2  0.0353 -0.1005 -0.0798  0.1063
#      Lag 3  0.0343 -0.1389 -0.0049 -0.0798
# META Lag 1 -0.3755 -0.3015  0.2122     0.0
#      Lag 2  -0.283 -0.5638 -0.1532  0.2122
#      Lag 3 -0.5615 -0.4992 -0.4712 -0.1532
# WMT  Lag 1  0.2236 -0.0456  -0.115  0.0131
#      Lag 2  0.2169  0.1677 -0.1554 -0.1034
#      Lag 3  0.2794  0.1613  0.0334 -0.1443

# %% [markdown]
# It is also possible to get trailing results. E.g. the TTM Earnings per Share ratio can be acquired by setting trailing to 4 (quarters). Note that this does not lead to meaningful results when using yearly data and therefore this image now shows the 4 year trailing result. Set `quarterly=True` in the Toolkit initialization to use quarterly data.

# %%
companies.ratios.get_earnings_per_share(trailing=4).T.dropna().plot(
    figsize=(15, 3),
    title="4 Year Trailing Earnings per Share for Apple, Amazon, META and Walmart",
    grid=True,
    linestyle="-",
    linewidth=2,
    xlabel="Date",
    ylabel="Earnings per Share",
)

companies.ratios.get_earnings_per_share(trailing=4, growth=True).T.dropna().plot(
    figsize=(15, 3),
    title="4 Year Trailing Earnings per Share Growth for Apple, Amazon, META and Walmart",
    grid=True,
    linestyle="-",
    linewidth=2,
    xlabel="Date",
    ylabel="Earnings per Share Growth",
)
# Out:
# <Axes: title={'center': '4 Year Trailing Earnings per Share Growth for Apple, Amazon, META and Walmart'}, xlabel='Date', ylabel='Earnings per Share Growth'>

# %% [markdown]
# It is possible to define custom ratios if the current ratio calculations are not sufficient. Define how each custom ratio needs to be calculated. This can be any of the following structures:
#
# - **Simple operations such as:** `'Quick Assets': 'Cash and Short Term Investments + Accounts Receivable'`
# - **Working with multiple operations:** `'Cash Op Expenses':'Cost of Goods Sold + Selling, General and Administrative Expenses - Depreciation and Amortization'`,
# - **Using curly brackets:** `'WC / Net Income as %': '(Working Capital / Net Income) * 100'`,
# - **Defining a criteria:** `'Large Revenues': 'Revenue > 1000000000'`,
# - **Using actual numbers:**  `'Daily Cash Op Expenses': 'Cash Op Expenses / 365'`,
# - **Combining earlier defined formulas:** `'Defensive Interval':'Quick Assets / Daily Cash Op Expenses'`
#
# Not that it is important you follow the NAME - FORMULA format and that you adhere to the financial statement naming. See some of the available fields you can use below, shrunken down for readability.

# %%
companies.ratios.collect_custom_ratios(options=True)[10:15]
# Out:
# The following names are available to be used in the Custom Ratios calculations.
# ['CAPEX per Share',
#  'Capital Expenditure',
#  'Capital Lease Obligations',
#  'Cash Beginning of Period',
#  'Cash Conversion Cycle']

# %% [markdown]
# Then create your custom ratios and add them to custom ratios function.

# %%
custom_ratios = {
    "WC / Net Income as %": "(Working Capital / Net Income) * 100",
    "Large Revenues": "Revenue > 1000000000",
    "Quick Assets": "Cash and Short Term Investments + Accounts Receivable",
    "Cash Op Expenses": "Cost of Goods Sold + Selling, General and Administrative Expenses "
    "- Depreciation and Amortization",
    "Daily Cash Op Expenses": "Cash Op Expenses / 365",
    "Defensive Interval": "Quick Assets / Daily Cash Op Expenses",
}

companies.ratios.collect_custom_ratios(custom_ratios_dict=custom_ratios)
# Out:
#                                       2005           2006           2007  \
# AAPL WC / Net Income as %         513.0271       405.5304       362.6896
#      Large Revenues                    1.0            1.0            1.0
#      Quick Assets             9573000000.0  12955000000.0  19415000000.0
#      Cash Op Expenses        11568000000.0  15925000000.0  18498000000.0
#      Daily Cash Op Expenses  31693150.6849  43630136.9863  50679452.0548
#      Defensive Interval           302.0526       296.9278       383.0941
# AMZN WC / Net Income as %         309.3093       442.6316       304.6218
#      Large Revenues                    1.0            1.0            1.0
#      Quick Assets             2274000000.0   2418000000.0   3817000000.0
#      Cash Op Expenses         7890000000.0  10107000000.0  13925000000.0
#      Daily Cash Op Expenses  21616438.3562  27690410.9589  38150684.9315
#      Defensive Interval           105.1977        87.3226       100.0506
# META WC / Net Income as %              NaN            NaN            NaN
#      Large Revenues                    0.0            0.0            0.0
#      Quick Assets                      NaN            NaN            NaN
#      Cash Op Expenses                  NaN            NaN    196000000.0
#      Daily Cash Op Expenses            NaN            NaN    536986.3014
#      Defensive Interval                NaN            NaN            NaN
# WMT  WC / Net Income as %         -42.8265       -44.5374       -45.7816
#      Large Revenues                    1.0            1.0            1.0
#      Quick Assets             7203000000.0   8989000000.0  10213000000.0
#      Cash Op Expenses       266493000000.0 292407000000.0 322694000000.0
#      Daily Cash Op Expenses 730117808.2192 801115068.4932 884093150.6849
#      Defensive Interval             9.8655        11.2206         11.552
#
#                                       2008            2009            2010  \
# AAPL WC / Net Income as %         385.7054        351.4902        149.5468
#      Large Revenues                    1.0             1.0             1.0
#      Quick Assets            26815000000.0   28521000000.0   35544000000.0
#      Cash Op Expenses        24622000000.0   26843000000.0   44031000000.0
#      Daily Cash Op Expenses  67457534.2466   73542465.7534  120632876.7123
#      Defensive Interval           397.5093        387.8167         294.646
# AMZN WC / Net Income as %         218.7597        269.7339        292.9688
#      Large Revenues                    1.0             1.0             1.0
#      Quick Assets             4554000000.0    7354000000.0   10349000000.0
#      Cash Op Expenses        18061000000.0   22900000000.0   32124000000.0
#      Daily Cash Op Expenses  49482191.7808   62739726.0274   88010958.9041
#      Defensive Interval            92.0331        117.2144        117.5876
# META WC / Net Income as %              NaN             NaN        306.4356
#      Large Revenues                    0.0             0.0             1.0
#      Quick Assets                      NaN             NaN    2158000000.0
#      Cash Op Expenses          280000000.0     350000000.0     659000000.0
#      Daily Cash Op Expenses    767123.2877     958904.1096    1805479.4521
#      Defensive Interval                NaN             NaN       1195.2504
# WMT  WC / Net Income as %         -85.3743        -48.0672         -50.436
#      Large Revenues                    1.0             1.0             1.0
#      Quick Assets             9211000000.0   11180000000.0   12051000000.0
#      Cash Op Expenses       350486000000.0  376070000000.0  377107000000.0
#      Daily Cash Op Expenses 960235616.4384 1030328767.1233 1033169863.0137
#      Defensive Interval             9.5924         10.8509         11.6641
#
#                                        2011            2012            2013  \
# AAPL WC / Net Income as %           65.6508         45.7935         79.9957
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             37669000000.0   47821000000.0   61187000000.0
#      Cash Op Expenses         70216000000.0   94609000000.0  110679000000.0
#      Daily Cash Op Expenses  192372602.7397   259202739.726  303230136.9863
#      Defensive Interval            195.8127        184.4926         201.784
# AMZN WC / Net Income as %          411.0935      -5882.0513         600.365
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             12147000000.0   14812000000.0   17214000000.0
#      Cash Op Expenses         45978000000.0   47116000000.0   55190000000.0
#      Daily Cash Op Expenses  125967123.2877  129084931.5068  151205479.4521
#      Defensive Interval             96.4299        114.7462        113.8451
# META WC / Net Income as %             370.5       31921.875        802.8169
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets              4455000000.0   10796000000.0   12558000000.0
#      Cash Op Expenses          1244000000.0    2503000000.0    2642000000.0
#      Daily Cash Op Expenses    3408219.1781    6857534.2466    7238356.1644
#      Defensive Interval           1307.1342       1574.3268       1734.9243
# WMT  WC / Net Income as %           -40.216         -46.659        -69.8747
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             12484000000.0   12487000000.0   14549000000.0
#      Cash Op Expenses        388666000000.0  412262000000.0  432860000000.0
#      Daily Cash Op Expenses 1064838356.1644 1129484931.5068 1185917808.2192
#      Defensive Interval             11.7238         11.0555         12.2681
#
#                                        2014            2015            2016  \
# AAPL WC / Net Income as %           12.8651         16.4213         60.9867
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             52296000000.0   71944000000.0   96454000000.0
#      Cash Op Expenses        116305000000.0  143161000000.0  135770000000.0
#      Daily Cash Op Expenses  318643835.6164  392221917.8082  371972602.7397
#      Defensive Interval            164.1205        183.4268         259.304
# AMZN WC / Net Income as %        -1343.5685        305.0336         82.8764
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             23028000000.0   25462000000.0   34320000000.0
#      Cash Op Expenses         63890000000.0   72371000000.0   89814000000.0
#      Daily Cash Op Expenses  175041095.8904  198276712.3288  246065753.4247
#      Defensive Interval            131.5577        128.4165        139.4749
# META WC / Net Income as %          418.6667        537.6669        309.4425
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             12877000000.0   20993000000.0   33442000000.0
#      Cash Op Expenses          3563000000.0    4942000000.0    6950000000.0
#      Daily Cash Op Expenses    9761643.8356   13539726.0274   19041095.8904
#      Defensive Interval           1319.1426       1550.4745       1756.3065
# WMT  WC / Net Income as %            -50.93         -12.186        -29.8081
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             13958000000.0   15913000000.0   14329000000.0
#      Cash Op Expenses        440552000000.0  449331000000.0  448571000000.0
#      Daily Cash Op Expenses 1206991780.8219 1231043835.6164 1228961643.8356
#      Defensive Interval             11.5643         12.9264         11.6594
#
#                                        2017            2018            2019  \
# AAPL WC / Net Income as %           57.5603         25.8857         103.339
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets            109854000000.0  115296000000.0  146361000000.0
#      Cash Op Expenses        146909000000.0  171161000000.0  168727000000.0
#      Daily Cash Op Expenses  402490410.9589  468934246.5753  462265753.4247
#      Defensive Interval            272.9357        245.8682        316.6166
# AMZN WC / Net Income as %           76.2941         66.6137         73.5416
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             44150000000.0   57927000000.0   75837000000.0
#      Cash Op Expenses        114199000000.0  141965000000.0  167828000000.0
#      Daily Cash Op Expenses  312873972.6027  388945205.4795   459802739.726
#      Defensive Interval            141.1111        148.9336        164.9338
# META WC / Net Income as %          281.4259        196.5673        276.8299
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             47543000000.0   48701000000.0   64373000000.0
#      Cash Op Expenses          9671000000.0   16337000000.0   27370000000.0
#      Daily Cash Op Expenses    26495890.411   44758904.1096   74986301.3699
#      Defensive Interval           1794.3537        1088.074        858.4635
# WMT  WC / Net Income as %          -67.7197       -191.2087       -233.5832
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             12702000000.0   12370000000.0   14005000000.0
#      Cash Op Expenses        453029000000.0  469377000000.0  481770000000.0
#      Daily Cash Op Expenses 1241175342.4658 1285964383.5616 1319917808.2192
#      Defensive Interval             10.2338          9.6192         10.6105
#
#                                        2020            2021            2022  \
# AAPL WC / Net Income as %           66.7485          9.8807        -18.6137
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets            128388000000.0  114145000000.0  109236000000.0
#      Cash Op Expenses        178419000000.0  223670000000.0  237536000000.0
#      Daily Cash Op Expenses  488819178.0822  612794520.5479  650783561.6438
#      Defensive Interval            262.6493        186.2696         167.853
# AMZN WC / Net Income as %           29.7595         57.8887        316.0176
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets            108938000000.0  128940000000.0  112386000000.0
#      Cash Op Expenses        236803000000.0  279285000000.0  301039000000.0
#      Daily Cash Op Expenses  648775342.4658  765164383.5616  824764383.5616
#      Defensive Interval            167.9133        168.5128        136.2644
# META WC / Net Income as %          208.2241         115.649        140.1853
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             73289000000.0   62037000000.0   54204000000.0
#      Cash Op Expenses         27985000000.0   38554000000.0   43641000000.0
#      Daily Cash Op Expenses   76671232.8767  105627397.2603  119564383.5616
#      Defensive Interval            955.8865        587.3192        453.3457
# WMT  WC / Net Income as %         -107.4121        -19.0822         -46.142
#      Large Revenues                     1.0             1.0             1.0
#      Quick Assets             15749000000.0   24257000000.0   23040000000.0
#      Cash Op Expenses        492409000000.0  525451000000.0  536154000000.0
#      Daily Cash Op Expenses 1349065753.4247 1439591780.8219 1468915068.4932
#      Defensive Interval              11.674         16.8499          15.685
#
#                                        2023            2024
# AAPL WC / Net Income as %            -1.796        -24.9691
#      Large Revenues                     1.0             1.0
#      Quick Assets            122540000000.0  131414000000.0
#      Cash Op Expenses        227550000000.0  225004000000.0
#      Daily Cash Op Expenses  623424657.5342  616449315.0685
#      Defensive Interval            196.5594        213.1789
# AMZN WC / Net Income as %           24.4339             NaN
#      Large Revenues                     1.0             0.0
#      Quick Assets            139033000000.0             NaN
#      Cash Op Expenses        312262000000.0             NaN
#      Daily Cash Op Expenses  855512328.7671             NaN
#      Defensive Interval            162.5143             NaN
# META WC / Net Income as %          136.5927             NaN
#      Large Revenues                     1.0             0.0
#      Quick Assets             81572000000.0             NaN
#      Cash Op Expenses         38490000000.0             NaN
#      Daily Cash Op Expenses  105452054.7945             NaN
#      Defensive Interval            773.5459             NaN
# WMT  WC / Net Income as %         -141.6353       -100.1741
#      Large Revenues                     1.0             1.0
#      Quick Assets             16818000000.0   18663000000.0
#      Cash Op Expenses        579916000000.0  609260000000.0
#      Daily Cash Op Expenses 1588810958.9041 1669205479.4521
#      Defensive Interval             10.5853         11.1808

# %% [markdown]
# It is also relatively straight forward to use the actual models provided you have the data available to flow through these functions. While the `Toolkit` class itself parses data from Financial Modeling Prep, if you utilize the individual models you can provide your own data as well while reaching the same results.

# %%
from financetoolkit.ratios import (
    efficiency_model,
    liquidity_model,
    profitability_model,
    solvency_model,
    valuation_model,
)

# Note: this is dummy data, not actual data

asset_turnover = efficiency_model.get_asset_turnover_ratio(
    sales=pd.Series([100, 110, 120, 130, 80]),
    total_assets_begin=pd.Series([500, 400, 300, 200, 100]),
    total_assets_end=pd.Series([500, 430, 320, 200, 100]),
)

quick_ratio = liquidity_model.get_quick_ratio(
    cash_and_equivalents=pd.Series([100, 110, 120, 130, 80]),
    accounts_receivable=pd.Series([30, 20, 30, 20, 40]),
    marketable_securities=pd.Series([30, 10, 30, 20, 40]),
    current_liabilities=pd.Series([130, 120, 110, 150, 100]),
)

return_on_assets = profitability_model.get_return_on_assets(
    net_income=pd.Series([80, 40, 40, 30, 20]),
    total_assets_begin=pd.Series([150, 200, 300, 400, 500]),
    total_assets_end=pd.Series([200, 300, 400, 500, 450]),
)

debt_to_assets = solvency_model.get_debt_to_assets_ratio(
    total_debt=pd.Series([100, 110, 120, 130, 80]),
    total_assets=pd.Series([200, 140, 160, 160, 300]),
)

price_to_earnings = valuation_model.get_price_earnings_ratio(
    stock_price=pd.Series([30, 11, 12, 10, 30]),
    earnings_per_share=pd.Series([0.5, 0.4, 0.1, 1.1, 1.2]),
)

components = {
    "Asset Turnover": asset_turnover,
    "Quick Ratio": quick_ratio,
    "Return on Assets": return_on_assets,
    "Debt to Assets": debt_to_assets,
    "Price to Earnings": price_to_earnings,
}


pd.DataFrame(components)
# Out:
#        Asset Turnover        Quick Ratio     Return on Assets  \
# 0                 0.2 1.2307692307692308  0.45714285714285713
# 1 0.26506024096385544 1.1666666666666667                 0.16
# 2  0.3870967741935484 1.6363636363636365  0.11428571428571428
# 3                0.65 1.1333333333333333  0.06666666666666667
# 4                 0.8                1.6 0.042105263157894736
#
#        Debt to Assets  Price to Earnings
# 0                 0.5               60.0
# 1  0.7857142857142857               27.5
# 2                0.75              120.0
# 3              0.8125   9.09090909090909
# 4 0.26666666666666666               25.0
