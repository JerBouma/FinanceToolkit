# %% [markdown]
# ![Finance Toolkit](https://github.com/JerBouma/FinanceToolkit/assets/46355364/198d47bd-e1b3-492d-acc4-5d9f02d1d009)
#
# **The FinanceToolkit** is an open-source toolkit in which all relevant financial ratios (100+), indicators and performance measurements are written down in the most simplistic way allowing for complete transparency of the calculation method. This allows you to not have to rely on metrics from other providers and, given a financial statement, allow for efficient manual calculations. This leads to one uniform method of calculation being applied that is available and understood by everyone.

# %% [markdown]
# # Installation
# To install the FinanceToolkit it simply requires the following:
#
# ```
# pip install financetoolkit -U
# ```
#
# From within Python use:
#
# ```python
# from financetoolkit import Toolkit
# ```
#
# To be able to get started, you need to obtain an API Key from FinancialModelingPrep. This is used to gain access to 30+ years of financial statement both annually and quarterly. Note that the Free plan is limited to 250 requests each day, 5 years of data and only features companies listed on US exchanges.
#
# ___
#
# <b><div align="center">Obtain an API Key from FinancialModelingPrep <a href="https://www.jeroenbouma.com/fmp" target="_blank">here</a>.</div></b>
# ___
#
# Through the link you are able to subscribe for the free plan and also premium plans at a **15% discount**. This is an affiliate link and thus supports the project at the same time. I have chosen FinancialModelingPrep as a source as I find it to be the most transparent, reliable and at an affordable price. When you notice that data is inaccurate or have any other issue related to the data, note that I simply provide the means to access this data and I am not responsible for the accuracy of the data itself. For this, use <a href="https://site.financialmodelingprep.com/contact" target="_blank">their contact form</a> or provide the data yourself.
#
# The current Notebook is revolved around the Portfolio class. If you are interested in the other modules, you can find the related Notebooks below. **Please view the documentation <a href="https://www.jeroenbouma.com/projects/financetoolkit/docs/portfolio" target="_blank">here</a> to find all the available indicators.**
#
# <style>
# .button {
#   color: #fff !important;
#   background-color: #58abc4;
#   display: inline-block;
#   margin-bottom: 0.25em;
#   padding: 0.5em 1em;
#   font-family: -apple-system,BlinkMacSystemFont,"Roboto","Segoe UI","Helvetica Neue","Lucida Grande",Arial,sans-serif;
#   font-size: .75em;
#   font-weight: bold;
#   text-align: center;
#   text-decoration: none;
#   border-width: 0;
#   border-radius: 4px;
#   cursor: pointer;
# }
#
# .button-current {
#   background-color: #d67f05;
# }
#
# a:hover {
#   color: #fff !important;
#   font-weight: normal !important;
# }
# </style>
#
# <div style="display: flex; justify-content: space-between;" class="show-on-desktop">
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//getting-started" target="_blank" class="button" style="flex: 1;margin-right:5px"">Toolkit</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//discovery-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Discovery</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//ratios-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Ratios</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//models-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Models</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//options-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Options</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//technicals-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Technicals</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//risk-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Risk</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//performance-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Performance</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//economics-module"  target="_blank" class="button" style="flex: 1;margin-right:5px">Economics</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//fixed-income-module" target="_blank" class="button" style="flex: 1;margin-right:5px">Fixed income</a>
#     <a href="https://www.jeroenbouma.com/projects/financetoolkit//portfolio-module" target="_blank" class="button button-current" style="flex: 1; ">Portfolio</a>
# </div>

# %%
from financetoolkit import Portfolio

API_KEY = "FINANCIAL_MODELING_PREP_API_KEY"

# %% [markdown]
# The Portfolio Module is meant to be used for the analysis of your own portfolio. This can be a portfolio of stocks, bonds, real estate or any other type of asset. The module allows you to create overviews to understand performance (as opposed to a benchmark) and see your profit-and-loss over time. It also allows you to directly connect to the Toolkit functionalities itself meaning that you can calculate any of the 150+ metrics for the assets in your portfolio and your actual portfolio (weighted average over time).
#
# **It is important to note that you will need a specific XLSX, XLS or CSV template in which you provide the data of your portfolio. This template can be acquired by not providing a `portfolio_dataset` parameter as follows.**

# %%
portfolio = Portfolio(api_key=API_KEY, benchmark_ticker="^GSPC")
# Out:
# No portfolio dataset provided thus loading the example portfolio for demonstration purposes.
# Please find the templates in your current directory under the names 'portfolio_template.xlsx' and 'portfolio_template.csv'.
# Choose your preferred format and provide the path within the portfolio_dataset parameter.

# %% [markdown]
# As written above, it provides an example portfolio and places two files, `portfolio_template.xlsx` and `portfolio_template.csv`, in the current working directory. This template can be used to fill in your own portfolio data. The template consists of the following columns:
#
# - `Date`: The date of the transaction (e.g. 2021-01-01)
# - `Identifier`: The ticker of the traded asset (e.g. AAPL)
# - `Currency`: The currency of the asset (e.g. USD)
# - `Volume`: The amount of shares or contracts (e.g. 10 for buy orders, and -10 for sell orders)
# - `Price`: The price of the asset at the time of the transaction (e.g. 100)
# - `Costs`: The costs of the transaction (e.g. -3)
#
# If you open the XLSX file you will see the following structure (the CSV has the same format):
#
# | Date       | Identifier | Currency | Volume | Price | Costs  |
# | ---------- | ---------- | -------- | ------ | ----- | ------ |
# | 2000-01-07 | ASML       | USD      | 9.00   | 30.82 | \-3.00 |
# | 2000-01-10 | SKY        | USD      | 12.00  | 15.23 | \-2.00 |
# | 2000-01-28 | AMZN       | USD      | 8.00   | 3.06  | \-3.00 |
# | 2000-02-23 | FIX        | USD      | 8.00   | 6.99  | 0.00   |
# | 2000-02-28 | MSFT       | USD      | 13.00  | 28.35 | 0.00   |
# | 2000-03-31 | FIX        | USD      | 9.00   | 5.14  | \-1.00 |
# | 2000-04-06 | SKY        | USD      | 11.00  | 13.70 | \-2.00 |
# | 2000-04-27 | AMD        | USD      | 10.00  | 42.81 | \-3.00 |
# | 2000-05-08 | AAPL       | USD      | 5.00   | 0.83  | \-2.00 |
# | 2000-06-01 | FICO       | USD      | 15.00  | 12.14 | \-3.00 |
# | 2000-06-07 | SKY        | USD      | \-1.00 | 14.04 | \-1.00 |
#
# By adjusting this template with your own assets (for the Identifier column, I recommend looking up your assets on [Yahoo Finance](https://finance.yahoo.com/)) you will then be able to use the Portfolio Module and calculate all the metrics for your portfolio. If you run into issues, please ensure that you do not change the format of the columns or the column names.
#
# For this Notebook, we proceed with the example portfolio that is provided in the template. We will calculate the metrics for this portfolio and provide an overview of the performance. Let's start off by getting an overal impression of the assets in the portfolio and their performance.

# %%
portfolio.get_portfolio_overview(include_portfolio=True)
# Out:
# Obtaining historical data: 100%|██████████| 26/26 [00:02<00:00,  9.30it/s]
#             Volume  Costs    Price    Invested  Latest Price  Latest Value  \
# Identifier
# AAPL         137.0  -28.0  38.9692   5310.7824        184.38      25260.06
# ALGN          81.0  -34.0 117.3645   9472.5274        153.06      12397.86
# AMD           78.0  -30.0  11.9075    898.7835         85.73       6686.94
# AMZN         116.0  -28.0  41.5471   4791.4596      178.3534    20688.9944
# ASML         129.0  -25.0  33.3184   4273.0691         625.0       80625.0
# AVGO          66.0  -24.0  21.2611   1379.2318      164.7068    10870.6488
# BAC           80.0  -30.0  20.0851   1576.8066         35.95        2876.0
# BLDR          48.0  -18.0  32.1805   1526.6658        118.73       5699.04
# CAMT          42.0  -19.0  10.0213     401.896        55.285       2321.97
# CWST          63.0   -8.0  20.1348   1260.4926        107.71       6785.73
# ...

# %% [markdown]
# The above overview demonstrates how each of your assets has performed and is an aggregation of all your transactions. The same transactions have occurred against the benchmark, which is the S&P 500 in this case. The benchmark is used to compare the performance of your portfolio against a broad market index which gives an indication whether your decisions have been fruitful. At the bottom you can find the `Portfolio` value which shows the performance of your portfolio itself, weighted by the assets in the portfolio.

# %% [markdown]
# The same overview can also be obtained for each transaction with `get_transactions_overview` which also demonstrates the Profit and Loss (PnL) of your transactions. This can be useful to see which transactions have been profitable and which have not. Here, you have the option to define the PnL method which can be either FIFO (First In First Out), LIFO (Last In First Out) or Average (Average Cost). By default, FIFO is used.

# %%
portfolio.get_transactions_overview(pnl_method="FIFO")
# Out:
#                        Name    Price  Volume  Costs Currency  Invested Amount  \
# Date       Identifier
# 2000-01-07 ASML        ASML  30.8212     9.0   -3.0      USD         274.3908
# 2000-01-10 SKY          SKY  15.2328    12.0   -2.0      USD         180.7941
# 2000-01-28 AMZN        AMZN   3.0558     8.0   -3.0      USD          21.4462
# 2000-02-23 FIX          FIX   6.9855     8.0    0.0      USD          55.8839
# 2000-02-28 MSFT        MSFT   28.354    13.0    0.0      USD         368.6021
# ...                     ...      ...     ...    ...      ...              ...
# 2024-06-11 META        META 505.5737     8.0    0.0      USD        4044.5892
# 2024-06-18 MPWR        MPWR 847.6002    14.0   -1.0      USD       11865.4026
# 2024-07-30 AMD          AMD 139.5702     3.0    0.0      USD         418.7105
# 2024-10-25 MCHI        MCHI  48.8436     6.0    0.0      USD         293.0617
# 2024-11-13 VOO          VOO 552.1364    11.0    0.0      USD        6073.5001
#
# ...

# %% [markdown]
# For both the portfolio and the transactions overviews, you can also see the performance per period. This can be `yearly`, `quarterly`, `monthly`, `weekly` or `daily`. This gives you deeper insights on the performance of your portfolio and your transactions in a specified period.

# %%
display(portfolio.get_portfolio_performance(period="yearly"))

display(portfolio.get_transactions_performance(period="quarterly"))
# Out:
#                  Volume  Costs  Invested Amount  Current Value  \
# Date Identifier
# 2000 AAPL           5.0   -2.0           2.1366          1.119
#      AMD           15.0   -4.0         534.7492         207.15
#      AMZN           8.0   -3.0          21.4462         6.2248
#      ASML           9.0   -3.0         274.3908         185.22
#      BAC           17.0   -3.0         185.8266          212.5
# ...                 ...    ...              ...            ...
# 2025 OXY           38.0   -4.0        1424.4454        1442.86
#      SKY          136.0  -19.0         2455.752       11660.64
#      VOO           79.0  -12.0        18660.827       37333.03
#      VSS          109.0  -19.0        8393.9862       11623.76
#      WMT          101.0  -14.0        1747.6345        8630.45
#
#                  Invested Weight  Current Weight  Return
# Date Identifier
# 2000 AAPL                 0.0008          0.0007 -0.4763
#      AMD                  0.2109          0.1244 -0.6126
# ...

# %% [markdown]
# Ultimately, what makes this module powerful is the ability to directly connect to the Toolkit functionalities. This means that you can calculate any of the 150+ metrics for the assets in your portfolio and your actual portfolio (weighted average over time). This can be done as follows where it is important you assign the toolkit to a new variable to prevent constant API calls.

# %%
toolkit = portfolio.toolkit

# %% [markdown]
# Then, it is possible to calculate anything but let's start with acquiring the Net Profit Margin ratio for the assets in the portfolio. It is important to note that the example portfolio contains ETFs as well meaning not for all tickers the ratios can be calculated.

# %%
net_profit_margin = toolkit.ratios.get_net_profit_margin()

display(net_profit_margin)

net_profit_margin.loc["Portfolio"].plot(
    title="Net Profit Margin of the Portfolio",
    kind="bar",
    figsize=(15, 5),
    rot=45,
    color="skyblue",
    alpha=0.7,
)
# Out:
# Obtaining financial statements:  33%|███▎      | 1/3 [00:13<00:27, 13.76s/it]
# The balance sheet statement from the following tickers are converted: ASML (EUR to USD)
# Obtaining financial statements:  67%|██████▋   | 2/3 [00:17<00:08,  8.11s/it]
# The income statement from the following tickers are converted: ASML (EUR to USD)
# Obtaining financial statements: 100%|██████████| 3/3 [00:21<00:00,  7.05s/it]
# The cash flow statement from the following tickers are converted: ASML (EUR to USD)
# date          2000    2001    2002    2003    2004    2005    2006    2007  \
# AAPL        0.0985 -0.0069  0.0113  0.0111  0.0321  0.0953   0.103  0.1456
# ALGN      -13.1654 -2.1015 -0.9035  -0.164  0.0507  0.0068 -0.1694  0.1256
# AMD         0.2117 -0.0156 -0.4831  -0.078  0.0182  0.0283 -0.0294 -0.5619
# AMZN        -0.511 -0.1783 -0.0381  0.0066   0.085  0.0392  0.0177  0.0321
# ASML        0.1599 -0.2597 -0.1061 -0.1039  0.0955  0.1232  0.1737  0.1806
# ...

# %% [markdown]
# We can do something similar with the Performance & Risk metrics as well with the added benefit that it becomes possible to compare the results to the benchmark again. This shows whether you might have a higher or lower risk profile compared to the benchmark. A good way to demonstrate this is through the calculation of the Beta and the Value at Risk.

# %%
beta = toolkit.performance.get_beta()

# The benchmark has a beta of 1 by definition
beta["Benchmark"] = 1

beta[["Benchmark", "Portfolio"]].plot(
    title="Beta", figsize=(15, 5), rot=0, color=["black", "green"], grid=True
)

value_at_risk = toolkit.risk.get_value_at_risk()

value_at_risk[["Benchmark", "Portfolio"]].plot(
    title="Value at Risk",
    kind="bar",
    figsize=(15, 5),
    rot=45,
    color=["skyblue", "salmon"],
    alpha=0.7,
    grid=True,
)
# Out:
# <Axes: title={'center': 'Value at Risk'}>

# %% [markdown]
# Furthermore, this can be extended in the Technicals module as well where you can calculate the Moving Averages, RSI, MACD and more for the assets in your portfolio. This can be useful to see whether the assets are overbought or oversold and whether the assets are in a bullish or bearish trend.

# %%
from matplotlib import pyplot as plt

rsi = toolkit.technicals.get_relative_strength_index()

rsi.plot(
    subplots=True,
    figsize=(15, 10),
    title="Relative Strength Index",
    alpha=0.7,
    layout=(7, 4),
    legend=False,
)

for ax, col in zip(plt.gcf().axes, rsi.columns):
    ax.axhline(y=70, color="black", linestyle="-")
    ax.axhline(y=30, color="black", linestyle="-")
    ax.set_title(col)
    ax.tick_params(axis="x", rotation=45)
    ax.set_ylim(0, 100)

plt.tight_layout()
plt.show()
