# %% [markdown]
# ![Finance Toolkit](https://github.com/JerBouma/FinanceToolkit/assets/46355364/198d47bd-e1b3-492d-acc4-5d9f02d1d009)
#
# **The FinanceToolkit** has an abundance of financial ratios, however it could be that you are looking for a specific ratio that is currently not provided. First and foremost, I encourage to [create a Pull Request](https://github.com/JerBouma/FinanceToolkit/pulls) to add these ratios in but there is also an option to add custom ratios as follows.

# %% [markdown]
# # Installation
# To install the FinanceToolkit it simply requires the following:
#
# ```
# pip install financetoolkit -U
# ```
#
# From within Python use:
#
# ```python
# from financetoolkit import Toolkit
# ```
#
# To be able to get started, you need to obtain an API Key from FinancialModelingPrep. This is used to gain access to 30+ years of financial statement both annually and quarterly. Note that the Free plan is limited to 250 requests each day, 5 years of data and only features companies listed on US exchanges.
#
# ___
#
# <b><div align="center">Obtain an API Key from FinancialModelingPrep <a href="https://site.financialmodelingprep.com/developer/docs/pricing/jeroen/">here</a>.</div></b>
# ___
#
# Through the link you are able to subscribe for the free plan and also premium plans at a **15% discount**. This is an affiliate link and thus supports the project at the same time. I have chosen FinancialModelingPrep as a source as I find it to be the most transparent, reliable and at an affordable price. When you notice that data is inaccurate or have any other issue related to the data, note that I simply provide the means to access this data and I am not responsible for the accuracy of the data itself. For this, use [their contact form](https://site.financialmodelingprep.com/contact) or provide the data yourself.

# %%
from financetoolkit import Toolkit

API_KEY = "FINANCIAL_MODELING_PREP_API_KEY"

# %% [markdown]
# Define how each custom ratio needs to be calculated. This can be any of the following structures:
#
# - **Simple operations such as:** `'Quick Assets': 'Cash and Short Term Investments + Accounts Receivable'`
# - **Working with multiple operations:** `'Cash Op Expenses':'Cost of Goods Sold + Selling, General and Administrative Expenses - Depreciation and Amortization'`,
# - **Using curly brackets:** `'WC / Net Income as %': '(Working Capital / Net Income) * 100'`,
# - **Defining a criteria:** `'Large Revenues': 'Revenue > 1000000000'`,
# - **Using actual numbers:**  `'Daily Cash Op Expenses': 'Cash Op Expenses / 365'`,
# - **Combining earlier defined formulas:** `'Defensive Interval':'Quick Assets / Daily Cash Op Expenses'`
#
# Not that it is important you follow the NAME - FORMULA format and that you adhere to the normalization files naming. This can be viewed relatively easy by initializing the Toolkit and running for example `get_balance_sheet_statement`.

# %%
custom_ratios = {
    'WC / Net Income as %': '(Working Capital / Net Income) * 100',
    'Large Revenues': 'Revenue > 1000000000',
    'Quick Assets': 'Cash and Short Term Investments + Accounts Receivable',
    'Cash Op Expenses':'Cost of Goods Sold + Selling, General and Administrative Expenses '
    '- Depreciation and Amortization',
    'Daily Cash Op Expenses': 'Cash Op Expenses / 365',
    'Defensive Interval':'Quick Assets / Daily Cash Op Expenses'
}

# %% [markdown]
# Initializing only is required once. This is the case for any function so once you have obtained a balance sheet statement, it will be stored accordingly which means that requests to FinancialModelingPrep, the source used in these examples, are kept to a minimum.
#
# Make sure to set the parameter `custom_ratios` with the above dictionary. Note that `quarterly=True` doesn't work without a Premium plan.

# %%
# Initialize the Toolkit with company tickers
companies = Toolkit(
    ["AAPL", "MSFT", "GOOGL", "AMZN"], api_key=API_KEY, start_date="2000-01-01",
    custom_ratios=custom_ratios, quarterly=True
)

# %% [markdown]
# By then running `ratios.collect_custom_ratios` it automatically calculates the given ratios. Note the ratios `Daily Cash Op Expenses` and `Defensive Interval` which rely on an earlier defined ratio (`Cash Op Expenses`). This is an example of how you can create a custom ratio based on another custom ratio.

# %%
companies.ratios.collect_custom_ratios()
# Out:
# Obtaining balance data:   0%|          | 0/4 [00:00<?, ?it/s]
# Obtaining balance data: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Obtaining income data: 100%|██████████| 4/4 [00:02<00:00,  1.65it/s]
# Obtaining cashflow data: 100%|██████████| 4/4 [00:02<00:00,  1.56it/s]
# The following data was not provided within the Toolkit class and thus was retrieved from FinancialModelingPrep: Balance Sheet Statement, Income Statement, Cash Flow Statement.
#                                           2000Q1              2000Q2  \
# AAPL  Cash Op Expenses              2035000000.0        1662000000.0
#       Daily Cash Op Expenses   5575342.465753425   4553424.657534246
#       Defensive Interval       816.4520884520884   999.0282791817089
#       Large Revenues                        True                True
#       Quick Assets                  4552000000.0        4549000000.0
#       WC / Net Income as %    1608.7431693989072  1312.8755364806868
# AMZN  Cash Op Expenses              1420000000.0        2719000000.0
#       Daily Cash Op Expenses  3890410.9589041094   7449315.068493151
#       Defensive Interval       6196.517605633803  3630.9378447958807
#       Large Revenues                        True                True
#       Quick Assets                 24107000000.0       27048000000.0
#       WC / Net Income as %     591.7819706498951   853.1755915317559
# GOOGL Cash Op Expenses                       NaN                 NaN
#       Daily Cash Op Expenses                 NaN                 NaN
#       Defensive Interval                     NaN                 NaN
#       Large Revenues                       False               False
#       Quick Assets                           NaN                 NaN
#       WC / Net Income as %                   NaN                 NaN
# MSFT  Cash Op Expenses               585672000.0         574296000.0
#       Daily Cash Op Expenses  1604580.8219178081   1573413.698630137
#       Defensive Interval       628.7505036949009   576.8482890356192
#       Large Revenues                       False               False
#       Quick Assets                  1008881000.0         907621000.0
#       WC / Net Income as %   -228.18643106103588 -176.24375756658594
#
#                                          2000Q3             2000Q4  \
# AAPL  Cash Op Expenses             1667000000.0       1301000000.0
#       Daily Cash Op Expenses  4567123.287671233 3564383.5616438356
#       Defensive Interval     1090.4019196160768  1264.173712528824
#       Large Revenues                       True               True
#       Quick Assets                 4980000000.0       4506000000.0
#       WC / Net Income as %    2055.294117647059 -1588.888888888889
# AMZN  Cash Op Expenses             1567000000.0       1923000000.0
#       Daily Cash Op Expenses  4293150.684931506  5268493.150684931
#       Defensive Interval      6494.763880025527  5890.109204368175
#       Large Revenues                       True               True
#       Quick Assets                27883000000.0      31032000000.0
#       WC / Net Income as %   1001.2239347234814  967.6448170731707
# GOOGL Cash Op Expenses                      NaN                NaN
#       Daily Cash Op Expenses                NaN                NaN
#       Defensive Interval                    NaN                NaN
#       Large Revenues                      False              False
#       Quick Assets                          NaN                NaN
#       WC / Net Income as %                  NaN                NaN
# MSFT  Cash Op Expenses              608337000.0        929243000.0
#       Daily Cash Op Expenses 1666676.7123287672 2545871.2328767125
#       Defensive Interval      540.0111451383033 432.27716539161446
#       Large Revenues                      False              False
#       Quick Assets                  900024000.0       1100522000.0
#       WC / Net Income as %   -209.5375097703348 -70.83923395824925
#
#                                           2001Q1             2001Q2  \
# AAPL  Cash Op Expenses              1316000000.0       1296000000.0
#       Daily Cash Op Expenses  3605479.4520547944 3550684.9315068494
#       Defensive Interval      1326.0372340425533  1356.358024691358
#       Large Revenues                        True               True
#       Quick Assets                  4781000000.0       4816000000.0
#       WC / Net Income as %     8255.813953488372  5957.377049180328
# AMZN  Cash Op Expenses              1423000000.0       2748000000.0
#       Daily Cash Op Expenses  3898630.1369863013  7528767.123287671
#       Defensive Interval       8605.586788475053  4684.830786026201
#       Large Revenues                        True               True
#       Quick Assets                 33550000000.0      35271000000.0
#       WC / Net Income as %     1144.390044879641 43853.846153846156
# GOOGL Cash Op Expenses                       NaN                NaN
#       Daily Cash Op Expenses                 NaN                NaN
#       Defensive Interval                     NaN                NaN
#       Large Revenues                       False              False
#       Quick Assets                           NaN                NaN
#       WC / Net Income as %                   NaN                NaN
# MSFT  Cash Op Expenses               509437000.0        476068000.0
#       Daily Cash Op Expenses   1395717.808219178 1304295.8904109588
#       Defensive Interval      460.67550060164456 466.89482384869393
#       Large Revenues                       False              False
#       Quick Assets                   642973000.0        608969000.0
#       WC / Net Income as %   -112.25000894422381 -95.69847765786207
#
#                                          2001Q3             2001Q4  \
# AAPL  Cash Op Expenses             1251000000.0       1214000000.0
#       Daily Cash Op Expenses 3427397.2602739725  3326027.397260274
#       Defensive Interval     1401.0631494804156  1462.705930807249
#       Large Revenues                       True               True
#       Quick Assets                 4802000000.0       4865000000.0
#       WC / Net Income as %    5492.424242424242   9718.42105263158
# AMZN  Cash Op Expenses             1934000000.0       3561000000.0
#       Daily Cash Op Expenses  5298630.136986301  9756164.383561645
#       Defensive Interval     7507.2233712512925  4440.679584386408
#       Large Revenues                       True               True
#       Quick Assets                39778000000.0      43324000000.0
#       WC / Net Income as %   2452.8448947778643 1595.3131844064828
# GOOGL Cash Op Expenses                      NaN                NaN
#       Daily Cash Op Expenses                NaN                NaN
#       Defensive Interval                    NaN                NaN
#       Large Revenues                      False              False
#       Quick Assets                          NaN                NaN
#       WC / Net Income as %                  NaN                NaN
# MSFT  Cash Op Expenses              602156000.0        838500000.0
#       Daily Cash Op Expenses 1649742.4657534247 2297260.2739726026
#       Defensive Interval     404.97229953699707  433.8145796064401
#       Large Revenues                       True               True
#       Quick Assets                  668100000.0        996585000.0
#       WC / Net Income as %   -142.5044444706076  5632.121092982111
#
#                                           2002Q1              2002Q2  ...  \
# AAPL  Cash Op Expenses              1327000000.0        1282000000.0  ...
#       Daily Cash Op Expenses  3635616.4383561644  3512328.7671232875  ...
#       Defensive Interval      1362.3549359457422  1404.1965678627146  ...
#       Large Revenues                        True                True  ...
#       Quick Assets                  4953000000.0        4932000000.0  ...
#       WC / Net Income as %                9262.5           11640.625  ...
# AMZN  Cash Op Expenses              2733000000.0        2412000000.0  ...
#       Daily Cash Op Expenses   7487671.232876712   6608219.178082191  ...
#       Defensive Interval       5732.489937797292   6625.234245439469  ...
#       Large Revenues                        True                True  ...
#       Quick Assets                 42923000000.0       43781000000.0  ...
#       WC / Net Income as %     1314.280496712929   2349.639344262295  ...
# GOOGL Cash Op Expenses                20000000.0          39000000.0  ...
#       Daily Cash Op Expenses  54794.520547945205  106849.31506849315  ...
#       Defensive Interval                     NaN                 NaN  ...
#       Large Revenues                       False               False  ...
#       Quick Assets                           NaN                 NaN  ...
#       WC / Net Income as %                   NaN                 NaN  ...
# MSFT  Cash Op Expenses               665464000.0         636499000.0  ...
#       Daily Cash Op Expenses  1823189.0410958903  1743832.8767123288  ...
#       Defensive Interval      408.76616916918124  472.28092267230585  ...
#       Large Revenues                       False               False  ...
#       Quick Assets                   745258000.0         823579000.0  ...
#       WC / Net Income as %   -1241.0463028683562 -409.44170683997305  ...
#
#                                          2022Q3              2022Q4  \
# AAPL  Cash Op Expenses            55626000000.0       70513000000.0
#       Daily Cash Op Expenses        152400000.0    193186301.369863
#       Defensive Interval      716.7716535433071   546.2861458170834
#       Large Revenues                       True                True
#       Quick Assets               109236000000.0      105535000000.0
#       WC / Net Income as %   -89.65300902466097 -28.365224348289885
# AMZN  Cash Op Expenses            18576000000.0       21856000000.0
#       Daily Cash Op Expenses  50893150.68493151   59879452.05479452
#       Defensive Interval      2721.839739448751   2260.224423499268
#       Large Revenues                       True                True
#       Quick Assets               138523000000.0      135341000000.0
#       WC / Net Income as %    418.2216905901116   463.3485540334855
# GOOGL Cash Op Expenses            36925000000.0       42495000000.0
#       Daily Cash Op Expenses 101164383.56164384  116424657.53424658
#       Defensive Interval      1506.805010155721  1322.9156371337804
#       Large Revenues                       True                True
#       Quick Assets               152435000000.0      154020000000.0
#       WC / Net Income as %    719.8418404025881   700.9321785085143
# MSFT  Cash Op Expenses            74139000000.0       88646000000.0
#       Daily Cash Op Expenses 203120547.94520548  242865753.42465752
#       Defensive Interval      466.7966926988495  462.74947544164434
#       Large Revenues                       True                True
#       Quick Assets                94816000000.0      112386000000.0
#       WC / Net Income as %   -309.8885793871866  -3094.244604316547
#
#                                           2023Q1              2023Q2  \
# AAPL  Cash Op Expenses                       NaN       56163000000.0
#       Daily Cash Op Expenses                 NaN  153871232.87671232
#       Defensive Interval                     NaN   596.4142763029041
#       Large Revenues                       False                True
#       Quick Assets                           NaN       91771000000.0
#       WC / Net Income as %                   NaN -29.644039735099337
# AMZN  Cash Op Expenses             19972000000.0       21322000000.0
#       Daily Cash Op Expenses   54717808.21917808   58416438.35616438
#       Defensive Interval      2592.3370218305627  2738.0991464215367
#       Large Revenues                        True                True
#       Quick Assets                141847000000.0      159950000000.0
#       WC / Net Income as %    427.33482703972896  398.92435635675514
# GOOGL Cash Op Expenses             36722000000.0       37896000000.0
#       Daily Cash Op Expenses   100608219.1780822  103824657.53424658
#       Defensive Interval      1502.2430695495887    1513.47477306312
#       Large Revenues                        True                True
#       Quick Assets                151138000000.0      157136000000.0
#       WC / Net Income as %     618.7695169756163  495.85692508710804
# MSFT  Cash Op Expenses             69883000000.0       71731000000.0
#       Daily Cash Op Expenses  191460273.97260273  196523287.67123288
#       Defensive Interval       533.0139662006497   528.6650820426315
#       Large Revenues                        True                True
#       Quick Assets                102051000000.0      103895000000.0
#       WC / Net Income as %   -357.78688524590166 -114.90370370370371
#
#                                           2023Q3 1998Q4 1999Q1 1999Q2 1999Q3  \
# AAPL  Cash Op Expenses             48305000000.0    NaN    NaN    NaN    NaN
#       Daily Cash Op Expenses  132342465.75342466    NaN    NaN    NaN    NaN
#       Defensive Interval       768.2190249456578    NaN    NaN    NaN    NaN
#       Large Revenues                        True  False  False  False  False
#       Quick Assets                101668000000.0    NaN    NaN    NaN    NaN
#       WC / Net Income as %   -11.588954277953825    NaN    NaN    NaN    NaN
# AMZN  Cash Op Expenses                       NaN    NaN    NaN    NaN    NaN
#       Daily Cash Op Expenses                 NaN    NaN    NaN    NaN    NaN
#       Defensive Interval                     NaN    NaN    NaN    NaN    NaN
#       Large Revenues                       False  False  False  False  False
#       Quick Assets                           NaN    NaN    NaN    NaN    NaN
#       WC / Net Income as %                   NaN    NaN    NaN    NaN    NaN
# GOOGL Cash Op Expenses                       NaN    NaN    NaN    NaN    NaN
#       Daily Cash Op Expenses                 NaN    NaN    NaN    NaN    NaN
#       Defensive Interval                     NaN    NaN    NaN    NaN    NaN
#       Large Revenues                       False  False  False  False  False
#       Quick Assets                           NaN    NaN    NaN    NaN    NaN
#       WC / Net Income as %                   NaN    NaN    NaN    NaN    NaN
# MSFT  Cash Op Expenses                       NaN    NaN    NaN    NaN    NaN
#       Daily Cash Op Expenses                 NaN    NaN    NaN    NaN    NaN
#       Defensive Interval                     NaN    NaN    NaN    NaN    NaN
#       Large Revenues                       False  False  False  False  False
#       Quick Assets                           NaN    NaN    NaN    NaN    NaN
#       WC / Net Income as %                   NaN    NaN    NaN    NaN    NaN
#
#                              1999Q4
# AAPL  Cash Op Expenses          NaN
#       Daily Cash Op Expenses    NaN
#       Defensive Interval        NaN
#       Large Revenues          False
#       Quick Assets              NaN
#       WC / Net Income as %      NaN
# AMZN  Cash Op Expenses          NaN
#       Daily Cash Op Expenses    NaN
#       Defensive Interval        NaN
#       Large Revenues          False
#       Quick Assets              NaN
#       WC / Net Income as %      NaN
# GOOGL Cash Op Expenses          NaN
#       Daily Cash Op Expenses    NaN
#       Defensive Interval        NaN
#       Large Revenues          False
#       Quick Assets              NaN
#       WC / Net Income as %      NaN
# MSFT  Cash Op Expenses          NaN
#       Daily Cash Op Expenses    NaN
#       Defensive Interval        NaN
#       Large Revenues          False
#       Quick Assets              NaN
#       WC / Net Income as %      NaN
#
# [24 rows x 100 columns]

# %% [markdown]
# In case you forgot a ratio or would like to insert new ratios, you can directly pass the custom_ratios dictionary to the function.

# %%
new_custom_ratios = {
    'WC / Net Income': 'Working Capital / Net Income',
    'Low Revenues': 'Revenue < 1000000000',
    'Quick Assets': 'Cash and Short Term Investments + Accounts Receivable',
    'Cash Op Expenses':'Cost of Goods Sold + Selling, General and Administrative Expenses '
    '- Depreciation and Amortization',
    'Monthly Cash Op Expenses': 'Cash Op Expenses / 30',
    'Defensive Interval':'Quick Assets / Monthly Cash Op Expenses'
}

# %%
companies.ratios.collect_custom_ratios(custom_ratios_dict=new_custom_ratios)
# Out:
#                                            2000Q1              2000Q2  \
# AAPL  Cash Op Expenses               2035000000.0        1662000000.0
#       Defensive Interval         67.1056511056511   82.11191335740072
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses  67833333.33333333          55400000.0
#       Quick Assets                   4552000000.0        4549000000.0
#       WC / Net Income           16.08743169398907  13.128755364806867
# AMZN  Cash Op Expenses               1420000000.0        2719000000.0
#       Defensive Interval       509.30281690140845   298.4332475174697
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses 47333333.333333336   90633333.33333333
#       Quick Assets                  24107000000.0       27048000000.0
#       WC / Net Income          5.9178197064989515   8.531755915317559
# GOOGL Cash Op Expenses                        NaN                 NaN
#       Defensive Interval                      NaN                 NaN
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses                NaN                 NaN
#       Quick Assets                            NaN                 NaN
#       WC / Net Income                         NaN                 NaN
# MSFT  Cash Op Expenses                585672000.0         574296000.0
#       Defensive Interval        51.67812359136172   47.41218813991391
#       Low Revenues                           True                True
#       Monthly Cash Op Expenses         19522400.0          19143200.0
#       Quick Assets                   1008881000.0         907621000.0
#       WC / Net Income          -2.281864310610359 -1.7624375756658595
#
#                                            2000Q3              2000Q4  \
# AAPL  Cash Op Expenses               1667000000.0        1301000000.0
#       Defensive Interval        89.62207558488302  103.90468870099923
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses 55566666.666666664  43366666.666666664
#       Quick Assets                   4980000000.0        4506000000.0
#       WC / Net Income           20.55294117647059  -15.88888888888889
# AMZN  Cash Op Expenses               1567000000.0        1923000000.0
#       Defensive Interval        533.8162093171666   484.1185647425897
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses 52233333.333333336          64100000.0
#       Quick Assets                  27883000000.0       31032000000.0
#       WC / Net Income          10.012239347234814   9.676448170731707
# GOOGL Cash Op Expenses                        NaN                 NaN
#       Defensive Interval                      NaN                 NaN
#       Low Revenues                          False               False
#       Monthly Cash Op Expenses                NaN                 NaN
#       Quick Assets                            NaN                 NaN
#       WC / Net Income                         NaN                 NaN
# MSFT  Cash Op Expenses                608337000.0         929243000.0
#       Defensive Interval        44.38447768260027   35.52963003218749
#       Low Revenues                           True                True
#       Monthly Cash Op Expenses         20277900.0  30974766.666666668
#       Quick Assets                    900024000.0        1100522000.0
#       WC / Net Income          -2.095375097703348 -0.7083923395824926
#
#                                             2001Q1              2001Q2  \
# AAPL  Cash Op Expenses                1316000000.0        1296000000.0
#       Defensive Interval        108.98936170212767  111.48148148148148
#       Low Revenues                           False               False
#       Monthly Cash Op Expenses  43866666.666666664          43200000.0
#       Quick Assets                    4781000000.0        4816000000.0
#       WC / Net Income            82.55813953488372   59.57377049180328
# AMZN  Cash Op Expenses                1423000000.0        2748000000.0
#       Defensive Interval         707.3085031623331  385.05458515283846
#       Low Revenues                           False               False
#       Monthly Cash Op Expenses  47433333.333333336          91600000.0
#       Quick Assets                   33550000000.0       35271000000.0
#       WC / Net Income           11.443900448796409  438.53846153846155
# GOOGL Cash Op Expenses                         NaN                 NaN
#       Defensive Interval                       NaN                 NaN
#       Low Revenues                           False               False
#       Monthly Cash Op Expenses                 NaN                 NaN
#       Quick Assets                             NaN                 NaN
#       WC / Net Income                          NaN                 NaN
# MSFT  Cash Op Expenses                 509437000.0         476068000.0
#       Defensive Interval         37.86373977547764   38.37491702865977
#       Low Revenues                            True                True
#       Monthly Cash Op Expenses  16981233.333333332  15868933.333333334
#       Quick Assets                     642973000.0         608969000.0
#       WC / Net Income          -1.1225000894422381 -0.9569847765786207
#
#                                             2001Q3             2001Q4  \
# AAPL  Cash Op Expenses                1251000000.0       1214000000.0
#       Defensive Interval         115.1558752997602 120.22240527182868
#       Low Revenues                           False              False
#       Monthly Cash Op Expenses          41700000.0 40466666.666666664
#       Quick Assets                    4802000000.0       4865000000.0
#       WC / Net Income            54.92424242424242   97.1842105263158
# AMZN  Cash Op Expenses                1934000000.0       3561000000.0
#       Defensive Interval         617.0320579110652 364.98736310025276
#       Low Revenues                           False              False
#       Monthly Cash Op Expenses  64466666.666666664        118700000.0
#       Quick Assets                   39778000000.0      43324000000.0
#       WC / Net Income           24.528448947778642 15.953131844064828
# GOOGL Cash Op Expenses                         NaN                NaN
#       Defensive Interval                       NaN                NaN
#       Low Revenues                           False              False
#       Monthly Cash Op Expenses                 NaN                NaN
#       Quick Assets                             NaN                NaN
#       WC / Net Income                          NaN                NaN
# MSFT  Cash Op Expenses                 602156000.0        838500000.0
#       Defensive Interval        33.285394482492904  35.65599284436494
#       Low Revenues                           False              False
#       Monthly Cash Op Expenses  20071866.666666668         27950000.0
#       Quick Assets                     668100000.0        996585000.0
#       WC / Net Income          -1.4250444447060762  56.32121092982111
#
#                                             2002Q1             2002Q2  ...  \
# AAPL  Cash Op Expenses                1327000000.0       1282000000.0  ...
#       Defensive Interval        111.97437829691032 115.41341653666146  ...
#       Low Revenues                           False              False  ...
#       Monthly Cash Op Expenses  44233333.333333336 42733333.333333336  ...
#       Quick Assets                    4953000000.0       4932000000.0  ...
#       WC / Net Income                       92.625          116.40625  ...
# AMZN  Cash Op Expenses                2733000000.0       2412000000.0  ...
#       Defensive Interval         471.1635565312843  544.5398009950248  ...
#       Low Revenues                           False              False  ...
#       Monthly Cash Op Expenses          91100000.0         80400000.0  ...
#       Quick Assets                   42923000000.0      43781000000.0  ...
#       WC / Net Income           13.142804967129292  23.49639344262295  ...
# GOOGL Cash Op Expenses                  20000000.0         39000000.0  ...
#       Defensive Interval                       NaN                NaN  ...
#       Low Revenues                            True               True  ...
#       Monthly Cash Op Expenses   666666.6666666666          1300000.0  ...
#       Quick Assets                             NaN                NaN  ...
#       WC / Net Income                          NaN                NaN  ...
# MSFT  Cash Op Expenses                 665464000.0        636499000.0  ...
#       Defensive Interval         33.59721938376832  38.81761008265528  ...
#       Low Revenues                            True               True  ...
#       Monthly Cash Op Expenses  22182133.333333332 21216633.333333332  ...
#       Quick Assets                     745258000.0        823579000.0  ...
#       WC / Net Income          -12.410463028683562  -4.09441706839973  ...
#
#                                             2022Q3               2022Q4  \
# AAPL  Cash Op Expenses               55626000000.0        70513000000.0
#       Defensive Interval          58.9127386473951    44.90023116304795
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses        1854200000.0   2350433333.3333335
#       Quick Assets                  109236000000.0       105535000000.0
#       WC / Net Income          -0.8965300902466097 -0.28365224348289886
# AMZN  Cash Op Expenses               18576000000.0        21856000000.0
#       Defensive Interval        223.71285529715763   185.77187042459735
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses         619200000.0    728533333.3333334
#       Quick Assets                  138523000000.0       135341000000.0
#       WC / Net Income            4.182216905901116    4.633485540334855
# GOOGL Cash Op Expenses               36925000000.0        42495000000.0
#       Defensive Interval        123.84698713608667   108.73279209318743
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses  1230833333.3333333         1416500000.0
#       Quick Assets                  152435000000.0       154020000000.0
#       WC / Net Income           7.1984184040258805   7.0093217850851435
# MSFT  Cash Op Expenses               74139000000.0        88646000000.0
#       Defensive Interval        38.366851454699955   38.034203460957066
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses        2471300000.0   2954866666.6666665
#       Quick Assets                   94816000000.0       112386000000.0
#       WC / Net Income           -3.098885793871866  -30.942446043165468
#
#                                             2023Q1               2023Q2  \
# AAPL  Cash Op Expenses                         NaN        56163000000.0
#       Defensive Interval                       NaN    49.02035147695102
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses                 NaN         1872100000.0
#       Quick Assets                             NaN        91771000000.0
#       WC / Net Income                          NaN -0.29644039735099337
# AMZN  Cash Op Expenses               19972000000.0        21322000000.0
#       Defensive Interval        213.06879631484077   225.04924491135915
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses   665733333.3333334    710733333.3333334
#       Quick Assets                  141847000000.0       159950000000.0
#       WC / Net Income             4.27334827039729   3.9892435635675514
# GOOGL Cash Op Expenses               36722000000.0        37896000000.0
#       Defensive Interval        123.47203311366482   124.39518682710576
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses  1224066666.6666667         1263200000.0
#       Quick Assets                  151138000000.0       157136000000.0
#       WC / Net Income            6.187695169756163     4.95856925087108
# MSFT  Cash Op Expenses               69883000000.0        71731000000.0
#       Defensive Interval          43.8093670849849    43.45192455144916
#       Low Revenues                           False                False
#       Monthly Cash Op Expenses  2329433333.3333335   2391033333.3333335
#       Quick Assets                  102051000000.0       103895000000.0
#       WC / Net Income          -3.5778688524590163   -1.149037037037037
#
#                                              2023Q3 1998Q4 1999Q1 1999Q2  \
# AAPL  Cash Op Expenses                48305000000.0    NaN    NaN    NaN
#       Defensive Interval          63.14128972156091    NaN    NaN    NaN
#       Low Revenues                            False  False  False  False
#       Monthly Cash Op Expenses   1610166666.6666667    NaN    NaN    NaN
#       Quick Assets                   101668000000.0    NaN    NaN    NaN
#       WC / Net Income          -0.11588954277953825    NaN    NaN    NaN
# AMZN  Cash Op Expenses                          NaN    NaN    NaN    NaN
#       Defensive Interval                        NaN    NaN    NaN    NaN
#       Low Revenues                            False  False  False  False
#       Monthly Cash Op Expenses                  NaN    NaN    NaN    NaN
#       Quick Assets                              NaN    NaN    NaN    NaN
#       WC / Net Income                           NaN    NaN    NaN    NaN
# GOOGL Cash Op Expenses                          NaN    NaN    NaN    NaN
#       Defensive Interval                        NaN    NaN    NaN    NaN
#       Low Revenues                            False  False  False  False
#       Monthly Cash Op Expenses                  NaN    NaN    NaN    NaN
#       Quick Assets                              NaN    NaN    NaN    NaN
#       WC / Net Income                           NaN    NaN    NaN    NaN
# MSFT  Cash Op Expenses                          NaN    NaN    NaN    NaN
#       Defensive Interval                        NaN    NaN    NaN    NaN
#       Low Revenues                            False  False  False  False
#       Monthly Cash Op Expenses                  NaN    NaN    NaN    NaN
#       Quick Assets                              NaN    NaN    NaN    NaN
#       WC / Net Income                           NaN    NaN    NaN    NaN
#
#                                1999Q3 1999Q4
# AAPL  Cash Op Expenses            NaN    NaN
#       Defensive Interval          NaN    NaN
#       Low Revenues              False  False
#       Monthly Cash Op Expenses    NaN    NaN
#       Quick Assets                NaN    NaN
#       WC / Net Income             NaN    NaN
# AMZN  Cash Op Expenses            NaN    NaN
#       Defensive Interval          NaN    NaN
#       Low Revenues              False  False
#       Monthly Cash Op Expenses    NaN    NaN
#       Quick Assets                NaN    NaN
#       WC / Net Income             NaN    NaN
# GOOGL Cash Op Expenses            NaN    NaN
#       Defensive Interval          NaN    NaN
#       Low Revenues              False  False
#       Monthly Cash Op Expenses    NaN    NaN
#       Quick Assets                NaN    NaN
#       WC / Net Income             NaN    NaN
# MSFT  Cash Op Expenses            NaN    NaN
#       Defensive Interval          NaN    NaN
#       Low Revenues              False  False
#       Monthly Cash Op Expenses    NaN    NaN
#       Quick Assets                NaN    NaN
#       WC / Net Income             NaN    NaN
#
# [24 rows x 100 columns]
